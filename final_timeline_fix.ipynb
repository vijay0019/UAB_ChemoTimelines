# %% [markdown]
# This notebook is intended to do 5 final checks/fixes on the final timelines:
# - Deduplicate identical tuples
# - Remove tuples providing no additional info based on relation type (contains-1 uninformative)
# - Remove tuples providing no additional info based on mentions (general chemo mention uninformative)
# - Make sure all SACT mentions are actually present in gold entities list or Vijay's extracted entities list
# - Normalize all general chemo mentions to the first mention in the timeline

# %%
# import necessary stuff
import pandas as pd
import numpy as np
import copy
import os
import json

# %%
def deduplicate_identical_tuples(timeline):
    timeline_copy = copy.deepcopy(timeline)
    result = []
    while len(timeline_copy) > 0:
        pot_ele = timeline_copy.pop(0) # "first" element
        if pot_ele not in timeline_copy: # no duplicates
            result.append(pot_ele)
    return result

# %%
def remove_trivial_rels(timeline):
    # returns a new timeline w/ trivial rels removed
    result = []
    for triple in timeline:
        # If the relation is contains-1 (not as much info), make sure there isn't 
        # a corresponding triple with same SACT and date and more specific relation
        # (begins-on or ends-on).
        must_continue = False
        if triple[1] == 'contains-1':
            for other_triple in timeline:
                if (other_triple[0] == triple[0]) and (other_triple[1] in ['ends-on','begins-on']) and (other_triple[2] == triple[2]):
                    must_continue = True
                    break # out of inner for loop
        if must_continue:
            continue # doesn't add triple to result
        # If no reason to cancel, just add to result
        result.append(triple)
    return result

# %%
CHEMO_MENTIONS = {
    "chemotherapy",
    "chemo",
    "chem",
    "chemo therapy",
    "chemo-radiation",
    "chemo-rt",
    "chemoembolization",
    "chemorad",
    "chemoirradiation",
    "chemort",
    "chemotherapeutic",
    "chemotherap",
    "chemotherapies",
    "chemotherapeutic",
    "chemotherapy's",
    "chemotheray",
    "chemoradiation",
} # global set variable

def remove_trivial_mentions(timeline):
    result = []
    for triple in timeline:
        # If the SACT is  a general mention (not as much info), make sure there isn't 
        # a corresponding triple with same relation and date and more specific SACT
        # (anything not a general mention.
        must_continue = False
        if triple[0] in CHEMO_MENTIONS:
            for other_triple in timeline:
                if (other_triple[0] not in CHEMO_MENTIONS) and (other_triple[1] == triple[1]) and (other_triple[2] == triple[2]):
                    must_continue = True
                    break # out of inner for loop
        if must_continue:
            continue # doesn't add triple to result
        # If no reason to cancel, just add to result
        result.append(triple)
    return result

# %%
# Import in synonyms and make function to return synonyms dict for given
# list of SACTs
synonym_file = "/data/project/alstate/chemoTimeline2025/test_results/2025-03-27 10-53-33.concept_synonym_stage.csv"
synonym_df = pd.read_csv(synonym_file)
synonym_df['synonym_name_lower'] = synonym_df['synonym_name'].apply(lambda x: x.lower())
print(synonym_df.head())

def get_synonyms_dict(gold_sacts):
    # the keys will be the lowercase synonyms,and the values the corresponding gold sact
    result = dict()
    for sact in gold_sacts:
        # Check if it is a general chemo mention. 
        if sact in CHEMO_MENTIONS:
            for mention in CHEMO_MENTIONS:
                result[mention] = sact
        else:
            # Otherwise, check the synonym df
            pot_codes = list((synonym_df[synonym_df['synonym_name_lower'] == sact])['synonym_concept_code'])
            if len(pot_codes) > 0: # don't care if no synonyms
                code = pot_codes[0]
                all_syns = list((synonym_df[synonym_df['synonym_concept_code'] == code])['synonym_name_lower'])
                for syn in all_syns:
                    result[syn] = sact
    return result
# Out:
#    synonym_concept_id synonym_name  synonym_concept_code  \
# 0                 NaN      AMG 330                     1
# 1                 NaN      AMG-330                     1
# 2                 NaN       AMG330                     1
# 3                 NaN  Eluvixtamab                     1
# 4                 NaN      AZD5363                     2
#
#   synonym_vocabulary_id  language_concept_id valid_start_date valid_end_date  \
# 0                HemOnc              4180186       2019-05-27     2025-03-23
# 1                HemOnc              4180186       2023-08-19     2025-03-23
# 2                HemOnc              4180186       2023-08-19     2025-03-23
# 3                HemOnc              4180186       2019-05-27     2025-03-23
# 4                HemOnc              4180186       2019-06-24     2025-03-23
#
#   invalid_reason synonym_name_lower
# 0              U            amg 330
# 1              U            amg-330
# 2              U             amg330
# 3              U        eluvixtamab
# 4              U            azd5363

# %%
def remove_ungold_mentions_and_rels(timeline,gold_sact,gold_rel):
    # returns a new timeline with tuples removed if they have a
    # mention or rel that doesn't appear in gold sacts or rels
    result = []
    syns_dict = get_synonyms_dict(gold_sact)
    for ele in timeline:
        if (ele[1] in gold_rel):
            if ele[0] in gold_sact:
                result.append(ele)
            else:
                # Change the sact if it is a synonym of a gold sact but not an actual gold sact
                if ele[0] in syns_dict:
                    new_ele = copy.deepcopy(ele)
                    new_ele[0] = syns_dict[ele[0]]
                    result.append(new_ele)
        # Note: if ele[1] not in gold_rel, don't even look for synonyms 
    return result

def remove_ungold_rels(timeline,gold_rel):
    # In case we don't have gold_sact
    result = []
    syns_dict = get_synonyms_dict(gold_sact)
    for ele in timeline:
        if (ele[1] in gold_rel):
            result.append(ele) 
    return result

# %%
def normalize_general_mentions(timeline):
    result = []
    first_chemo_mention = None
    for ele in timeline:
        ele_copy = copy.deepcopy(ele)
        if ele_copy[0] in CHEMO_MENTIONS:
            if first_chemo_mention != None:
                ele_copy[0] = first_chemo_mention
            else:
                first_chemo_mention = ele_copy[0]
        result.append(ele_copy)
    return result

# %%
def get_all_gold_entities(base_dir,cancer,patient):
    # cancer should be in ["ovarian","breast","melanoma"]
    # patient should be a string: patient##
    
    # Bug: currently this gets all doc times and events; we want events only
    # Fix: look at the next line and if it is <type>EVENT</event> it's fine
    specific_dir = base_dir + cancer + "/"
    specific_dir = specific_dir + cancer + "_" + patient + "_test/"
    # There should be a list of folders, one for each note
    note_folders = os.listdir(specific_dir)
    all_entities = []
    for note_folder in note_folders:
        note_folder_path = os.path.join(specific_dir,note_folder)
        #print(note_folder_path)
        entities_file_name = note_folder_path + "/" + note_folder + ".Temporal_Relation.gold.entity_only.xml"
        note_name = note_folder_path + "/" + note_folder
        #print("My file name:",entities_file_name)
        #print("Files in there:",os.listdir(note_folder_path))
        # Open the xml file
        # Turns out we can do this w/o xml parsing
        #tree = ET.parse(entities_file_name)
        xml_lines = []
        with open(entities_file_name,"r") as file:
            xml_lines = file.readlines()
        # Open the note and read its contents
        note_contents = ""
        with open(note_name,"r") as file:
            note_contents = file.read()
        #root = tree.getroot()
        #anno = root.find('annotations') # the first and only one
        #for entity_and_more in anno.findall('entity'):
            #span_node = entity_and_more.find('span') # had issues getting attributes
        for line in xml_lines:
            # only care about lines with <span>. This should have start,end framed
            # by <span> on left and </span> on right
            stripped_line = line.strip()
            if "<span>" in stripped_line:
                span_str = stripped_line.split("<span>")[-1].split("</span>")[0]
                split_span = span_str.split(",")
                #print("split span:",split_span)
                start_i = int(split_span[0])
                end_i = int(split_span[1])
                entity = note_contents[start_i:end_i].lower()
                #print("Current entity:",entity)
                all_entities.append(entity)
            elif "<type>" in stripped_line:
                # If it is not of type EVENT, throw out the last entity (it is DOCTIME)
                type_str = stripped_line.split("<type>")[-1].split("</type>")[0]
                if type_str != "EVENT":
                    all_entities.pop()
    return list(set(all_entities))

# %%
def get_all_predicted_rels_all_patients(rels_file):
    # Note: rels_file should be the exact location of the json file,
    # not relative
    # Note: this doesn't do for all cancer types, just a single one
    # We can just evaluate the json and Python will turn it into a dict :)
    patient_rels_dict = dict()
    with open(rels_file,"r") as f:
        patient_rels_dict = eval(f.read())
    # We want to return a dict with just lists of rels for each patient
    result = dict()
    for patient in patient_rels_dict:
        # Values are timeline-like, but not normalized.
        # rels are the 2nd element of each triple
        timeline_like = patient_rels_dict[patient]
        curr_rels = []
        for triplet in timeline_like:
            curr_rels.append(triplet[1]) # python starts counting at 0
        curr_rels = list(set(curr_rels)) # deduplicate
        result[patient] = curr_rels
    return result

# %%
def get_all_predicted_entities_all_patients_all_cancers(entities_file):
    # Input is a csv.
    # Output is a dictionary of dictionaries:
    # {"breast":{"patient001":[SACTs]...}...}
    entities_df = pd.read_csv(entities_file) # note_path, events_list, timex_list
    result = {"breast":dict(),"ovarian":dict(),"melanoma":dict()}
    for row in entities_df.itertuples():
        curr_path = row.note_path
        curr_path_list = curr_path.split('/')
        # 4th from the end is the current cancer
        curr_cancer = curr_path_list[-4]
        # 2nd from the end is the current patient
        curr_patient = curr_path_list[-2]
        # Go through the events_list and add to growing list, deduplicated at the end
        pre_entities_list = eval(row.events_list) # now a list of dicts
        #if (curr_cancer == "ovarian" and curr_patient == "patient50"):
            #print("pre_entities_list:",pre_entities_list)
        entities_list = []
        for ele in pre_entities_list:
            curr_entity = ele['entity']
            entities_list.append(curr_entity)
        entities_list = list(set(entities_list))
        # Each (cancer, patient###) isn't be unique, as there can be multiple notes
        # for the same patient. Try appending it to the end of the dictionary value.
        # If this doesn't work, it hasn't been initialized -> initialize it. 
        try:
            (result[curr_cancer])[curr_patient].extend(entities_list)
        except:
            (result[curr_cancer])[curr_patient] = entities_list
    # At the end, still need to do some deduplication due to multiple notes
    for cancer in result:
        for patient in result[cancer]:
            result[cancer][patient] = list(set(result[cancer][patient]))
    return result

# %%
def task1(timelines_file_dict,gold_entities_dir,tlinks_file_dict,final_timelines_dir,consider_entities=False):
    """timelines_file_dict and tlinks_file_dict should both be of
    the form: {"breast":<breast file>, "ovarian":<ovarian file>, "melanoma":<melanoma file>}.
    All file names should be exact, not relative.
    """
    timeline_count = 0
    fixed_timeline_count = 0
    for cancer in ["breast","ovarian","melanoma"]:
        # Obtain the dictionary of timelines
        timelines_dict = dict()
        with open(timelines_file_dict[cancer],"r") as f:
            timelines_dict = eval(f.read()) # it is a json, should evaluate to dict
        # Obtain tlinks - gold entities will be obtained on the fly
        tlinks_dict = get_all_predicted_rels_all_patients(tlinks_file_dict[cancer])
        result_dict = dict() # same format as the json
        for patient in timelines_dict:
            entities_and_rels_working = consider_entities
            curr_timeline = timelines_dict[patient]
            # ran into issue if there any no entities or no relations. 
            # tries to look up entities and can't find them. 
            # In this case, the timeline is [], so don't attempt to fix it
            # and add it directly to the timeline.
            if curr_timeline == []:
                result_dict[patient] = curr_timeline
                timeline_count += 1
                continue # skip the rest of the stuff this iteration
            curr_entities = None
            curr_tlinks = None
            try:
                curr_entities = get_all_gold_entities(gold_entities_dir,cancer,patient)
                curr_tlinks = tlinks_dict[patient]
            except:
                entities_and_rels_working = False
            fixed_timeline = deduplicate_identical_tuples(curr_timeline)
            fixed_timeline = remove_trivial_rels(fixed_timeline)
            fixed_timeline = remove_trivial_mentions(fixed_timeline)
            # if issue, then don't mess with these mentions and rels
            if entities_and_rels_working:
                fixed_timeline = remove_ungold_mentions_and_rels(fixed_timeline,curr_entities,curr_tlinks)
            fixed_timeline = normalize_general_mentions(fixed_timeline)
            if fixed_timeline != curr_timeline:
                print("Had to change timeline")
                print("Original timeline:",curr_timeline)
                print("Fixed timeline:",fixed_timeline)
                fixed_timeline_count += 1
            result_dict[patient] = fixed_timeline
            timeline_count += 1
        # Now results_dict should contain all we need. Need to output it as a json.
        split_input_name = timelines_file_dict[cancer].split("/")
        original_short_name = split_input_name[-1]
        final_short_name = original_short_name.split(".")[0] + "_final.json"
        final_long_name = final_timelines_dir + final_short_name
        result_str = json.dumps(result_dict)
        with open(final_long_name,"w") as f:
            f.write(result_str)
    print("Proportion of timelines that needed fixing:",fixed_timeline_count/timeline_count)

# %%
def task2(timelines_file_dict,predicted_entities_file,tlinks_file_dict,final_timelines_dir):
    """timelines_file_dict and tlinks_file_dict should both be of
    the form: {"breast":<breast file>, "ovarian":<ovarian file>, "melanoma":<melanoma file>}.
    All file names should be exact, not relative.
    """
    # The predicted entities are all in one file
    #entities_super_dict = get_all_predicted_entities_all_patients_all_cancers(predicted_entities_file)
    
    for cancer in ["breast","ovarian","melanoma"]:
        # Obtain the dictionary of timelines
        timelines_dict = dict()
        with open(timelines_file_dict[cancer],"r") as f:
            timelines_dict = eval(f.read()) # it is a json, should evaluate to dict
        # Obtain tlinks - gold entities will be obtained on the fly
        #tlinks_dict = get_all_predicted_rels_all_patients(tlinks_file_dict[cancer])
        result_dict = dict() # same format as the json
        for patient in timelines_dict:
            curr_timeline = timelines_dict[patient]
            #curr_entities = entities_super_dict[cancer][patient]
            #curr_tlinks = tlinks_dict[patient]
            fixed_timeline = deduplicate_identical_tuples(curr_timeline)
            fixed_timeline = remove_trivial_rels(fixed_timeline)
            fixed_timeline = remove_trivial_mentions(fixed_timeline)
            #fixed_timeline = remove_ungold_mentions_and_rels(fixed_timeline,curr_entities,curr_tlinks)
            fixed_timeline = normalize_general_mentions(fixed_timeline)
            if fixed_timeline != curr_timeline:
                print("Had to change timeline")
                print("Original timeline:",curr_timeline)
                print("Fixed timeline:",fixed_timeline)
            result_dict[patient] = fixed_timeline
        # Now results_dict should contain all we need. Need to output it as a json.
        split_input_name = timelines_file_dict[cancer].split("/")
        original_short_name = split_input_name[-1]
        final_short_name = original_short_name.split(".")[0] + "_final.json"
        final_long_name = final_timelines_dir + final_short_name
        result_str = json.dumps(result_dict)
        with open(final_long_name,"w") as f:
            f.write(result_str)

# %%
def task2_dev_test(timelines_file_dict,final_timelines_dir):
    """ Working with Chris's results on the dev data as a testing measure
    """
    timeline_count = 0
    fixed_timeline_count = 0
    for cancer in ["breast","ovarian","melanoma"]:
        # Obtain the dictionary of timelines
        timelines_dict = dict()
        with open(timelines_file_dict[cancer],"r") as f:
            timelines_dict = eval(f.read()) # it is a json, should evaluate to dict
        result_dict = dict() # same format as the json
        for patient in timelines_dict:
            curr_timeline = timelines_dict[patient]
            curr_tlinks = ["begins-on","ends-on","contains-1"] # most general case
            fixed_timeline = deduplicate_identical_tuples(curr_timeline)
            fixed_timeline = remove_trivial_rels(fixed_timeline)
            fixed_timeline = remove_trivial_mentions(fixed_timeline)
            fixed_timeline = remove_ungold_rels(fixed_timeline,curr_tlinks)
            fixed_timeline = normalize_general_mentions(fixed_timeline)
            if fixed_timeline != curr_timeline:
                print("Had to change timeline")
                print("Original timeline:",curr_timeline)
                print("Fixed timeline:",fixed_timeline)
                fixed_timeline_count += 1
            result_dict[patient] = fixed_timeline
            timeline_count += 1
        # Now results_dict should contain all we need. Need to output it as a json.
        split_input_name = timelines_file_dict[cancer].split("/")
        original_short_name = split_input_name[-1]
        final_short_name = original_short_name.split(".")[0] + "_final.json"
        final_long_name = final_timelines_dir + final_short_name
        result_str = json.dumps(result_dict)
        with open(final_long_name,"w") as f:
            f.write(result_str)
    print("Proportion of timelines that needed fixing:",fixed_timeline_count/timeline_count)

# %%
# Actually running stuff
# CHRIS EDIT HERE: you should only need to change the following two variables:
# - task1_timeline_input_file_dict
# - task2_timeline_input_file_dict

# Task 1
task1_timeline_input_file_dict = {
    "breast":"/data/project/alstate/chemoTimeline2025/test_results/final_timelines/subtask1_chris1/breast_test_all_patients_generated_timelines.json",
    "ovarian":"/data/project/alstate/chemoTimeline2025/test_results/final_timelines/subtask1_chris1/ovarian_test_all_patients_generated_timelines.json",
    "melanoma":"/data/project/alstate/chemoTimeline2025/test_results/final_timelines/subtask1_chris1/melanoma_test_all_patients_generated_timelines.json"
}
task1_gold_entities_dir = "/data/project/alstate/chemoTimeline2025/chemoTimelines2025_test_data/subtask1/Gold_PairWise_EventTimex/"
task1_tlinks_file_dict = {
    "breast":"/data/project/alstate/chemoTimeline2025/test_results/tlinks/breast_task1.json",
    "ovarian":"/data/project/alstate/chemoTimeline2025/test_results/tlinks/ovarian_task1.json",
    "melanoma":"/data/project/alstate/chemoTimeline2025/test_results/tlinks/melanoma_task1.json"
}
task1_final_timeline_dir = "/data/project/alstate/chemoTimeline2025/test_results/final_timelines/subtask1_chris1_final/"

task1(task1_timeline_input_file_dict,task1_gold_entities_dir,task1_tlinks_file_dict,task1_final_timeline_dir)

# Task 2
task2_timeline_input_file_dict = {
    "breast":"/data/project/alstate/chemoTimeline2025/test_results/timelines/<BREAST_FILE>.json",
    "ovarian":"/data/project/alstate/chemoTimeline2025/test_results/timelines/<OVARIAN_FILE>.json",
    "melanoma":"/data/project/alstate/chemoTimeline2025/test_results/timelines/<MELANOMA_FILE>.json"
}
task2_predicted_entities_file = "/data/project/alstate/chemoTimeline2025/test_results/events_mods_timex/"
task2_tlinks_file_dict = {
    "breast":"/data/project/alstate/chemoTimeline2025/test_results/tlinks/breast_task2.json",
    "ovarian":"/data/project/alstate/chemoTimeline2025/test_results/tlinks/ovarian_task2.json",
    "melanoma":"/data/project/alstate/chemoTimeline2025/test_results/tlinks/melanoma_task2.json"
}
task2_final_timeline_dir = "/data/project/alstate/chemoTimeline2025/test_results/final_timelines/"

#task2(task2_timeline_input_file_dict,task2_predicted_entities_file,task2_tlinks_file_dict,task2_final_timeline_dir)
# Out:
# Had to change timeline
# Original timeline: [['carboplatin', 'begins-on', '2012'], ['carboplatin', 'ends-on', '2012'], ['chemotherapy', 'ends-on', '2012'], ['herceptin', 'begins-on', '2012'], ['taxotere', 'begins-on', '2012'], ['taxotere', 'ends-on', '2012'], ['chemotherapy', 'ends-on', '2012-02'], ['chemotherapy', 'ends-on', '2012-02-01'], ['chemotherapy', 'ends-on', '2012-02-03'], ['chemo', 'begins-on', '2012-02-14'], ['chemo', 'begins-on', '2012-03-01'], ['arimidex', 'contains-1', '2012-03-15'], ['chemotherapy', 'contains-1', '2012-03-15'], ['arimidex', 'contains-1', '2012-04-12'], ['arimidex', 'begins-on', '2012-05-10'], ['chemotherapy', 'contains-1', '2012-05-23'], ['chemotherapy', 'begins-on', '2012-06'], ['carboplatin', 'begins-on', '2012-w25'], ['herceptin', 'begins-on', '2012-w25'], ['taxotere', 'begins-on', '2012-w25'], ['carboplatin', 'begins-on', '2012-07-05'], ['herceptin', 'begins-on', '2012-07-05'], ['taxotere', 'begins-on', '2012-07-05'], ['arimidex', 'contains-1', '2012-07-10'], ['carbo', 'begins-on', '2012-07-26'], ['herceptin', 'begins-on', '2012-07-26'], ['taxotere', 'begins-on', '2012-07-26'], ['carboplatin', 'contains-1', '2012-08-16'], ['herceptin', 'begins-on', '2012-08-16'], ['herceptin', 'contains-1', '2012-08-16'], ['taxotere', 'contains-1', '2012-08-16'], ['chemotherapy', 'contains-1', '2012-09'], ['chemotherapy', 'begins-on', '2012-09-04'], ['chemotherapy', 'begins-on', '2012-09-05'], ['carboplatin', 'begins-on', '2012-09-06'], ['chemo', 'contains-1', '2012-09-06'], ['herceptin', 'begins-on', '2012-09-06'], ['taxotere', 'begins-on', '2012-09-06'], ['tch', 'begins-on', '2012-09-06'], ['arimidex', 'contains-1', '2012-09-18'], ['chemo', 'contains-1', '2012-09-18'], ['chemotherapy', 'contains-1', '2012-09-18'], ['anastrozole', 'contains-1', '2012-09-19'], ['arimidex', 'contains-1', '2012-09-19'], ['carboplatin', 'contains-1', '2012-09-19'], ['chemo', 'contains-1', '2012-09-19'], ['chemotherapy', 'contains-1', '2012-09-19'], ['anastrozole', 'contains-1', '2012-09-20'], ['arimidex', 'contains-1', '2012-09-20'], ['carboplatin', 'contains-1', '2012-09-20'], ['arimidex', 'begins-on', '2012-09-22'], ['chemo', 'contains-1', '2012-09-22'], ['chemotherapy', 'contains-1', '2012-09-22'], ['anastrozole', 'begins-on', '2012-09-23'], ['chemotherapy', 'contains-1', '2012-09-23'], ['arimidex', 'contains-1', '2012-09-25'], ['chemotherapy', 'ends-on', '2012-09-25'], ['carboplatin', 'contains-1', '2012-09-27'], ['chemo', 'contains-1', '2012-09-27'], ['herceptin', 'contains-1', '2012-09-27'], ['taxotere', 'contains-1', '2012-09-27'], ['carboplatin', 'ends-on', '2012-10-12'], ['herceptin', 'ends-on', '2012-10-12'], ['taxotere', 'ends-on', '2012-10-12'], ['chemo', 'begins-on', '2012-10-29'], ['chemotherapy', 'begins-on', '2012-10-29'], ['chemotherapy', 'contains-1', '2012-11'], ['carboplatin', 'ends-on', '2012-11-01'], ['chemotherapy', 'contains-1', '2012-11-01'], ['herceptin', 'begins-on', '2012-11-01'], ['taxotere', 'ends-on', '2012-11-01'], ['arimidex', 'contains-1', '2012-11-23'], ['herceptin', 'begins-on', '2012-11-23'], ['arimidex', 'contains-1', '2012-12-13'], ['herceptin', 'contains-1', '2012-12-13']]
# Fixed timeline: [['carboplatin', 'begins-on', '2012'], ['carboplatin', 'ends-on', '2012'], ['herceptin', 'begins-on', '2012'], ['taxotere', 'begins-on', '2012'], ['taxotere', 'ends-on', '2012'], ['chemotherapy', 'ends-on', '2012-02'], ['chemotherapy', 'ends-on', '2012-02-01'], ['chemotherapy', 'ends-on', '2012-02-03'], ['chemotherapy', 'begins-on', '2012-02-14'], ['chemotherapy', 'begins-on', '2012-03-01'], ['arimidex', 'contains-1', '2012-03-15'], ['arimidex', 'contains-1', '2012-04-12'], ['arimidex', 'begins-on', '2012-05-10'], ['chemotherapy', 'contains-1', '2012-05-23'], ['chemotherapy', 'begins-on', '2012-06'], ['carboplatin', 'begins-on', '2012-w25'], ['herceptin', 'begins-on', '2012-w25'], ['taxotere', 'begins-on', '2012-w25'], ['carboplatin', 'begins-on', '2012-07-05'], ['herceptin', 'begins-on', '2012-07-05'], ['taxotere', 'begins-on', '2012-07-05'], ['arimidex', 'contains-1', '2012-07-10'], ['carbo', 'begins-on', '2012-07-26'], ['herceptin', 'begins-on', '2012-07-26'], ['taxotere', 'begins-on', '2012-07-26'], ['carboplatin', 'contains-1', '2012-08-16'], ['herceptin', 'begins-on', '2012-08-16'], ['taxotere', 'contains-1', '2012-08-16'], ['chemotherapy', 'contains-1', '2012-09'], ['chemotherapy', 'begins-on', '2012-09-04'], ['chemotherapy', 'begins-on', '2012-09-05'], ['carboplatin', 'begins-on', '2012-09-06'], ['chemotherapy', 'contains-1', '2012-09-06'], ['herceptin', 'begins-on', '2012-09-06'], ['taxotere', 'begins-on', '2012-09-06'], ['tch', 'begins-on', '2012-09-06'], ['arimidex', 'contains-1', '2012-09-18'], ['anastrozole', 'contains-1', '2012-09-19'], ['arimidex', 'contains-1', '2012-09-19'], ['carboplatin', 'contains-1', '2012-09-19'], ['anastrozole', 'contains-1', '2012-09-20'], ['arimidex', 'contains-1', '2012-09-20'], ['carboplatin', 'contains-1', '2012-09-20'], ['arimidex', 'begins-on', '2012-09-22'], ['chemotherapy', 'contains-1', '2012-09-22'], ['chemotherapy', 'contains-1', '2012-09-22'], ['anastrozole', 'begins-on', '2012-09-23'], ['chemotherapy', 'contains-1', '2012-09-23'], ['arimidex', 'contains-1', '2012-09-25'], ['chemotherapy', 'ends-on', '2012-09-25'], ['carboplatin', 'contains-1', '2012-09-27'], ['herceptin', 'contains-1', '2012-09-27'], ['taxotere', 'contains-1', '2012-09-27'], ['carboplatin', 'ends-on', '2012-10-12'], ['herceptin', 'ends-on', '2012-10-12'], ['taxotere', 'ends-on', '2012-10-12'], ['chemotherapy', 'begins-on', '2012-10-29'], ['chemotherapy', 'begins-on', '2012-10-29'], ['chemotherapy', 'contains-1', '2012-11'], ['carboplatin', 'ends-on', '2012-11-01'], ['chemotherapy', 'contains-1', '2012-11-01'], ['herceptin', 'begins-on', '2012-11-01'], ['taxotere', 'ends-on', '2012-11-01'], ['arimidex', 'contains-1', '2012-11-23'], ['herceptin', 'begins-on', '2012-11-23'], ['arimidex', 'contains-1', '2012-12-13'], ['herceptin', 'contains-1', '2012-12-13']]
# Had to change timeline
# Original timeline: [['chemotherapy', 'contains-1', '2009-10-28'], ['chemotherapy', 'contains-1', '2009-11'], ['chemotherapy', 'begins-on', '2010-01'], ['tc', 'begins-on', '2010-01'], ['cyclophosphamide', 'begins-on', '2010-01-01'], ['cytoxan', 'begins-on', '2010-01-01'], ['taxotere', 'begins-on', '2010-01-01'], ['tc', 'begins-on', '2010-01-01'], ['chemotherapy', 'contains-1', '2010-02-16'], ['tc', 'contains-1', '2010-02-16'], ['carboplatin', 'contains-1', '2010-03'], ['chemo', 'contains-1', '2010-03'], ['chemotherapy', 'begins-on', '2010-03'], ['taxotere', 'contains-1', '2010-03'], ['chemo', 'contains-1', '2010-03-09'], ['chemotherapy', 'begins-on', '2010-03-09'], ['chemotherapy', 'contains-1', '2010-03-09'], ['cytoxan', 'contains-1', '2010-03-09'], ['taxotere', 'contains-1', '2010-03-09'], ['tc', 'contains-1', '2010-03-09'], ['chemotherapy', 'ends-on', '2010-04'], ['chemotherapy', 'contains-1', '2010-05-19'], ['chemotherapy', 'contains-1', '2010-07-17'], ['taxotere', 'begins-on', '2010-07-17'], ['carboplatin', 'contains-1', '2010-09'], ['chemotherapy', 'contains-1', '2010-09'], ['taxotere', 'contains-1', '2010-09']]
# Fixed timeline: [['chemotherapy', 'contains-1', '2009-10-28'], ['chemotherapy', 'contains-1', '2009-11'], ['tc', 'begins-on', '2010-01'], ['cyclophosphamide', 'begins-on', '2010-01-01'], ['cytoxan', 'begins-on', '2010-01-01'], ['taxotere', 'begins-on', '2010-01-01'], ['tc', 'begins-on', '2010-01-01'], ['tc', 'contains-1', '2010-02-16'], ['carboplatin', 'contains-1', '2010-03'], ['chemotherapy', 'begins-on', '2010-03'], ['taxotere', 'contains-1', '2010-03'], ['chemotherapy', 'begins-on', '2010-03-09'], ['cytoxan', 'contains-1', '2010-03-09'], ['taxotere', 'contains-1', '2010-03-09'], ['tc', 'contains-1', '2010-03-09'], ['chemotherapy', 'ends-on', '2010-04'], ['chemotherapy', 'contains-1', '2010-05-19'], ['chemotherapy', 'contains-1', '2010-07-17'], ['taxotere', 'begins-on', '2010-07-17'], ['carboplatin', 'contains-1', '2010-09'], ['taxotere', 'contains-1', '2010-09']]
# Had to change timeline
# Original timeline: [['chemotherapy', 'begins-on', '2012'], ['arimidex', 'begins-on', '2012-06'], ['arimidex', 'ends-on', '2012-08-17'], ['chemotherapy', 'ends-on', '2012-12-04'], ['anastrozole', 'begins-on', '2012-12-14'], ['arimidex', 'begins-on', '2013-01-24'], ['arimidex', 'ends-on', '2013-02-04'], ['chemo', 'begins-on', '2013-02-28'], ['chemotherapy', 'begins-on', '2013-02-28'], ['adriamycin', 'begins-on', '2013-03-12'], ['cytoxan', 'begins-on', '2013-03-12'], ['adriamycin', 'begins-on', '2013-04-09'], ['cytoxan', 'begins-on', '2013-04-09'], ['adriamycin', 'contains-1', '2013-05-02'], ['cytoxan', 'contains-1', '2013-05-02'], ['adriamycin', 'begins-on', '2013-05-10'], ['cytoxan', 'begins-on', '2013-05-10'], ['chemotherapy', 'contains-1', '2013-06-06'], ['taxol', 'begins-on', '2013-06-27']]
# Fixed timeline: [['chemotherapy', 'begins-on', '2012'], ['arimidex', 'begins-on', '2012-06'], ['arimidex', 'ends-on', '2012-08-17'], ['chemotherapy', 'ends-on', '2012-12-04'], ['anastrozole', 'begins-on', '2012-12-14'], ['arimidex', 'begins-on', '2013-01-24'], ['arimidex', 'ends-on', '2013-02-04'], ['chemotherapy', 'begins-on', '2013-02-28'], ['chemotherapy', 'begins-on', '2013-02-28'], ['adriamycin', 'begins-on', '2013-03-12'], ['cytoxan', 'begins-on', '2013-03-12'], ['adriamycin', 'begins-on', '2013-04-09'], ['cytoxan', 'begins-on', '2013-04-09'], ['adriamycin', 'contains-1', '2013-05-02'], ['cytoxan', 'contains-1', '2013-05-02'], ['adriamycin', 'begins-on', '2013-05-10'], ['cytoxan', 'begins-on', '2013-05-10'], ['chemotherapy', 'contains-1', '2013-06-06'], ['taxol', 'begins-on', '2013-06-27']]
# Had to change timeline
# Original timeline: [['adriamycin', 'contains-1', '2013'], ['chemotherapy', 'contains-1', '2013'], ['cytoxan', 'contains-1', '2013'], ['taxol', 'contains-1', '2013'], ['ac', 'begins-on', '2013-01-31'], ['abraxane', 'begins-on', '2013-04'], ['ac', 'ends-on', '2013-04'], ['ac', 'contains-1', '2013-04-17'], ['adriamycin', 'contains-1', '2013-04-17'], ['chemotherapy', 'contains-1', '2013-04-17'], ['cytoxan', 'contains-1', '2013-04-17'], ['paclitaxel', 'contains-1', '2013-04-17'], ['tamoxifen', 'contains-1', '2013-04-17'], ['taxol', 'contains-1', '2013-04-17'], ['adriamycin', 'begins-on', '2013-04-24'], ['chemo', 'begins-on', '2013-04-24'], ['chemotherapy', 'begins-on', '2013-04-24'], ['cytoxan', 'begins-on', '2013-04-24'], ['adriamycin', 'begins-on', '2013-06-07'], ['cytoxan', 'begins-on', '2013-06-07'], ['adriamycin', 'begins-on', '2013-06-28'], ['adriamycin', 'ends-on', '2013-06-28'], ['chemotherapy', 'begins-on', '2013-06-28'], ['cytoxan', 'begins-on', '2013-06-28'], ['cytoxan', 'ends-on', '2013-06-28'], ['adriamycin', 'contains-1', '2013-07'], ['chemotherapy', 'contains-1', '2013-07'], ['cytoxan', 'contains-1', '2013-07'], ['taxol', 'begins-on', '2013-07-19'], ['adriamycin', 'contains-1', '2013-08-16'], ['cytoxan', 'contains-1', '2013-08-16'], ['taxol', 'contains-1', '2013-08-16'], ['taxol', 'begins-on', '2013-09'], ['abraxane', 'begins-on', '2013-09-13'], ['adriamycin', 'contains-1', '2013-09-13'], ['cytoxan', 'contains-1', '2013-09-13'], ['tamoxifen', 'contains-1', '2013-09-13'], ['taxol', 'ends-on', '2013-09-13'], ['tamoxifen', 'begins-on', '2013-10-11'], ['taxol', 'begins-on', '2013-10-11'], ['paclitaxel', 'contains-1', '2013-10-25'], ['chemotherapy', 'ends-on', '2013-11-04'], ['tamoxifen', 'contains-1', '2013-11-04'], ['taxol', 'ends-on', '2013-11-04'], ['tamoxifen', 'contains-1', '2013-11-15'], ['taxol', 'contains-1', '2013-11-15'], ['tamoxifen', 'begins-on', '2013-12'], ['tamoxifen', 'contains-1', '2013-12-10'], ['tamoxifen', 'contains-1', '2013-12-15']]
# Fixed timeline: [['adriamycin', 'contains-1', '2013'], ['cytoxan', 'contains-1', '2013'], ['taxol', 'contains-1', '2013'], ['ac', 'begins-on', '2013-01-31'], ['abraxane', 'begins-on', '2013-04'], ['ac', 'ends-on', '2013-04'], ['ac', 'contains-1', '2013-04-17'], ['adriamycin', 'contains-1', '2013-04-17'], ['cytoxan', 'contains-1', '2013-04-17'], ['paclitaxel', 'contains-1', '2013-04-17'], ['tamoxifen', 'contains-1', '2013-04-17'], ['taxol', 'contains-1', '2013-04-17'], ['adriamycin', 'begins-on', '2013-04-24'], ['cytoxan', 'begins-on', '2013-04-24'], ['adriamycin', 'begins-on', '2013-06-07'], ['cytoxan', 'begins-on', '2013-06-07'], ['adriamycin', 'begins-on', '2013-06-28'], ['adriamycin', 'ends-on', '2013-06-28'], ['cytoxan', 'begins-on', '2013-06-28'], ['cytoxan', 'ends-on', '2013-06-28'], ['adriamycin', 'contains-1', '2013-07'], ['cytoxan', 'contains-1', '2013-07'], ['taxol', 'begins-on', '2013-07-19'], ['adriamycin', 'contains-1', '2013-08-16'], ['cytoxan', 'contains-1', '2013-08-16'], ['taxol', 'contains-1', '2013-08-16'], ['taxol', 'begins-on', '2013-09'], ['abraxane', 'begins-on', '2013-09-13'], ['adriamycin', 'contains-1', '2013-09-13'], ['cytoxan', 'contains-1', '2013-09-13'], ['tamoxifen', 'contains-1', '2013-09-13'], ['taxol', 'ends-on', '2013-09-13'], ['tamoxifen', 'begins-on', '2013-10-11'], ['taxol', 'begins-on', '2013-10-11'], ['paclitaxel', 'contains-1', '2013-10-25'], ['tamoxifen', 'contains-1', '2013-11-04'], ['taxol', 'ends-on', '2013-11-04'], ['tamoxifen', 'contains-1', '2013-11-15'], ['taxol', 'contains-1', '2013-11-15'], ['tamoxifen', 'begins-on', '2013-12'], ['tamoxifen', 'contains-1', '2013-12-10'], ['tamoxifen', 'contains-1', '2013-12-15']]
# Had to change timeline
# Original timeline: [['arimidex', 'begins-on', '2007-12-18'], ['arimidex', 'contains-1', '2007-12-18'], ['arimidex', 'contains-1', '2008-04-01']]
# Fixed timeline: [['arimidex', 'begins-on', '2007-12-18'], ['arimidex', 'contains-1', '2008-04-01']]
# Had to change timeline
# Original timeline: [['chemotherapy', 'contains-1', '2008'], ['herceptin', 'contains-1', '2008'], ['chemotherapy', 'contains-1', '2008-11-07'], ['herceptin', 'contains-1', '2009-03'], ['chemo', 'ends-on', '2009-03-27'], ['anastrozole', 'begins-on', '2009-07-16'], ['arimidex', 'begins-on', '2009-07-20'], ['herceptin', 'begins-on', '2009-07-20']]
# Fixed timeline: [['herceptin', 'contains-1', '2008'], ['chemotherapy', 'contains-1', '2008-11-07'], ['herceptin', 'contains-1', '2009-03'], ['chemotherapy', 'ends-on', '2009-03-27'], ['anastrozole', 'begins-on', '2009-07-16'], ['arimidex', 'begins-on', '2009-07-20'], ['herceptin', 'begins-on', '2009-07-20']]
# Had to change timeline
# Original timeline: [['adriamycin', 'contains-1', '2012'], ['cyclophosphamide', 'contains-1', '2012'], ['chemotherapy', 'begins-on', '2012-10'], ['adriamycin', 'begins-on', '2012-11'], ['cytoxan', 'begins-on', '2012-11'], ['taxol', 'begins-on', '2012-11'], ['chemotherapy', 'contains-1', '2012-11-15'], ['adriamycin', 'begins-on', '2012-11-16'], ['cytoxan', 'begins-on', '2012-11-16'], ['ac', 'begins-on', '2012-12-07'], ['adriamycin', 'begins-on', '2012-12-07'], ['chemotherapy', 'begins-on', '2012-12-07'], ['cyclophosphamide', 'begins-on', '2012-12-07'], ['cytoxan', 'begins-on', '2012-12-07'], ['adriamycin', 'begins-on', '2012-12-14'], ['chemotherapy', 'begins-on', '2012-12-14'], ['cytoxan', 'begins-on', '2012-12-14'], ['taxol', 'begins-on', '2012-12-21'], ['ac', 'contains-1', '2013'], ['adriamycin', 'contains-1', '2013'], ['carboplatin', 'begins-on', '2013'], ['chemotherapy', 'contains-1', '2013'], ['cytoxan', 'contains-1', '2013'], ['gemcitabine', 'begins-on', '2013'], ['taxol', 'contains-1', '2013'], ['adriamycin', 'contains-1', '2013-01-04'], ['cytoxan', 'contains-1', '2013-01-04'], ['adriamycin', 'ends-on', '2013-02-14'], ['cytoxan', 'ends-on', '2013-02-14'], ['chemotherapy', 'ends-on', '2013-02-15'], ['cyclophosphamide', 'begins-on', '2013-02-15'], ['cyclophosphamide', 'ends-on', '2013-02-15'], ['doxorubicin', 'begins-on', '2013-02-15'], ['doxorubicin', 'ends-on', '2013-02-15'], ['adriamycin', 'ends-on', '2013-02-18'], ['cytoxan', 'ends-on', '2013-02-18'], ['taxol', 'begins-on', '2013-02-18'], ['paclitaxel', 'begins-on', '2013-03-07'], ['taxol', 'begins-on', '2013-03-07'], ['taxol', 'begins-on', '2013-03-29'], ['ac', 'ends-on', '2013-06'], ['ac', 'contains-1', '2013-06-12'], ['chemo', 'contains-1', '2013-06-12'], ['taxol', 'contains-1', '2013-06-12'], ['adriamycin', 'ends-on', '2013-06-26'], ['chemotherapy', 'contains-1', '2013-06-26'], ['chemotherapy', 'ends-on', '2013-06-26'], ['cyclophosphamide', 'ends-on', '2013-06-26'], ['cytoxan', 'ends-on', '2013-06-26'], ['doxorubicin', 'ends-on', '2013-06-26'], ['paclitaxel', 'contains-1', '2013-06-26'], ['paclitaxel', 'ends-on', '2013-06-26'], ['taxol', 'ends-on', '2013-06-26'], ['chemotherapy', 'begins-on', '2013-07'], ['taxol', 'ends-on', '2013-07'], ['adriamycin', 'contains-1', '2013-07-05'], ['adriamycin', 'ends-on', '2013-07-05'], ['chemo', 'contains-1', '2013-07-05'], ['chemo', 'ends-on', '2013-07-05'], ['cytoxan', 'contains-1', '2013-07-05'], ['cytoxan', 'ends-on', '2013-07-05'], ['taxol', 'contains-1', '2013-07-05'], ['taxol', 'ends-on', '2013-07-05'], ['taxol', 'begins-on', '2013-07-06'], ['chemotherapy', 'begins-on', '2013-09-05'], ['chemotherapy', 'begins-on', '2013-09-24'], ['carboplatin', 'begins-on', '2013-09-27'], ['carboplatin', 'contains-1', '2013-09-27'], ['gemcitabine', 'begins-on', '2013-09-27'], ['gemzar', 'begins-on', '2013-09-27'], ['gemzar', 'contains-1', '2013-09-27'], ['carboplatin', 'begins-on', '2013-11-01'], ['gemzar', 'begins-on', '2013-11-01'], ['chemotherapy', 'contains-1', '2013-11-12'], ['carboplatin', 'begins-on', '2013-11-22'], ['carboplatin', 'contains-1', '2013-11-22'], ['gemzar', 'begins-on', '2013-11-22'], ['gemzar', 'contains-1', '2013-11-22'], ['carboplatin', 'begins-on', '2013-12'], ['gemzar', 'begins-on', '2013-12'], ['carboplatin', 'contains-1', '2013-12-20'], ['gemcitabine', 'contains-1', '2013-12-20'], ['carboplatin', 'contains-1', '2014'], ['chemotherapy', 'contains-1', '2014'], ['cyclophosphamide', 'contains-1', '2014'], ['doxorubicin', 'contains-1', '2014'], ['gemcitabine', 'contains-1', '2014'], ['paclitaxel', 'contains-1', '2014'], ['chemotherapy', 'ends-on', '2014-01'], ['carboplatin', 'ends-on', '2014-01-03'], ['gemcitabine', 'ends-on', '2014-01-03'], ['gemzar', 'ends-on', '2014-01-03'], ['chemo', 'contains-1', '2014-03-19'], ['chemotherapy', 'contains-1', '2014-10-07']]
# Fixed timeline: [['adriamycin', 'contains-1', '2012'], ['cyclophosphamide', 'contains-1', '2012'], ['chemotherapy', 'begins-on', '2012-10'], ['adriamycin', 'begins-on', '2012-11'], ['cytoxan', 'begins-on', '2012-11'], ['taxol', 'begins-on', '2012-11'], ['chemotherapy', 'contains-1', '2012-11-15'], ['adriamycin', 'begins-on', '2012-11-16'], ['cytoxan', 'begins-on', '2012-11-16'], ['ac', 'begins-on', '2012-12-07'], ['adriamycin', 'begins-on', '2012-12-07'], ['cyclophosphamide', 'begins-on', '2012-12-07'], ['cytoxan', 'begins-on', '2012-12-07'], ['adriamycin', 'begins-on', '2012-12-14'], ['cytoxan', 'begins-on', '2012-12-14'], ['taxol', 'begins-on', '2012-12-21'], ['ac', 'contains-1', '2013'], ['adriamycin', 'contains-1', '2013'], ['carboplatin', 'begins-on', '2013'], ['cytoxan', 'contains-1', '2013'], ['gemcitabine', 'begins-on', '2013'], ['taxol', 'contains-1', '2013'], ['adriamycin', 'contains-1', '2013-01-04'], ['cytoxan', 'contains-1', '2013-01-04'], ['adriamycin', 'ends-on', '2013-02-14'], ['cytoxan', 'ends-on', '2013-02-14'], ['cyclophosphamide', 'begins-on', '2013-02-15'], ['cyclophosphamide', 'ends-on', '2013-02-15'], ['doxorubicin', 'begins-on', '2013-02-15'], ['doxorubicin', 'ends-on', '2013-02-15'], ['adriamycin', 'ends-on', '2013-02-18'], ['cytoxan', 'ends-on', '2013-02-18'], ['taxol', 'begins-on', '2013-02-18'], ['paclitaxel', 'begins-on', '2013-03-07'], ['taxol', 'begins-on', '2013-03-07'], ['taxol', 'begins-on', '2013-03-29'], ['ac', 'ends-on', '2013-06'], ['ac', 'contains-1', '2013-06-12'], ['taxol', 'contains-1', '2013-06-12'], ['adriamycin', 'ends-on', '2013-06-26'], ['cyclophosphamide', 'ends-on', '2013-06-26'], ['cytoxan', 'ends-on', '2013-06-26'], ['doxorubicin', 'ends-on', '2013-06-26'], ['paclitaxel', 'ends-on', '2013-06-26'], ['taxol', 'ends-on', '2013-06-26'], ['chemotherapy', 'begins-on', '2013-07'], ['taxol', 'ends-on', '2013-07'], ['adriamycin', 'ends-on', '2013-07-05'], ['cytoxan', 'ends-on', '2013-07-05'], ['taxol', 'ends-on', '2013-07-05'], ['taxol', 'begins-on', '2013-07-06'], ['chemotherapy', 'begins-on', '2013-09-05'], ['chemotherapy', 'begins-on', '2013-09-24'], ['carboplatin', 'begins-on', '2013-09-27'], ['gemcitabine', 'begins-on', '2013-09-27'], ['gemzar', 'begins-on', '2013-09-27'], ['carboplatin', 'begins-on', '2013-11-01'], ['gemzar', 'begins-on', '2013-11-01'], ['chemotherapy', 'contains-1', '2013-11-12'], ['carboplatin', 'begins-on', '2013-11-22'], ['gemzar', 'begins-on', '2013-11-22'], ['carboplatin', 'begins-on', '2013-12'], ['gemzar', 'begins-on', '2013-12'], ['carboplatin', 'contains-1', '2013-12-20'], ['gemcitabine', 'contains-1', '2013-12-20'], ['carboplatin', 'contains-1', '2014'], ['cyclophosphamide', 'contains-1', '2014'], ['doxorubicin', 'contains-1', '2014'], ['gemcitabine', 'contains-1', '2014'], ['paclitaxel', 'contains-1', '2014'], ['chemotherapy', 'ends-on', '2014-01'], ['carboplatin', 'ends-on', '2014-01-03'], ['gemcitabine', 'ends-on', '2014-01-03'], ['gemzar', 'ends-on', '2014-01-03'], ['chemotherapy', 'contains-1', '2014-03-19'], ['chemotherapy', 'contains-1', '2014-10-07']]
# Had to change timeline
# Original timeline: [['adriamycin', 'begins-on', '2012-03'], ['cytoxan', 'begins-on', '2012-03'], ['docetaxel', 'begins-on', '2012-03'], ['adriamycin', 'contains-1', '2013-03'], ['cytoxan', 'contains-1', '2013-03'], ['adriamycin', 'begins-on', '2013-03-07'], ['cytoxan', 'begins-on', '2013-03-07'], ['adriamycin', 'contains-1', '2013-03-28'], ['cytoxan', 'contains-1', '2013-03-28'], ['adriamycin', 'contains-1', '2013-04-18'], ['chemo', 'contains-1', '2013-04-18'], ['cytoxan', 'contains-1', '2013-04-18'], ['adriamycin', 'begins-on', '2013-05-09'], ['adriamycin', 'contains-1', '2013-05-09'], ['adriamycin', 'ends-on', '2013-05-09'], ['cytoxan', 'begins-on', '2013-05-09'], ['cytoxan', 'contains-1', '2013-05-09'], ['cytoxan', 'ends-on', '2013-05-09'], ['docetaxel', 'ends-on', '2013-05-09'], ['docetaxel', 'begins-on', '2013-05-30'], ['docetaxel', 'contains-1', '2013-05-30'], ['taxotere', 'begins-on', '2013-05-30'], ['taxotere', 'contains-1', '2013-05-30'], ['docetaxel', 'contains-1', '2013-06-06'], ['taxotere', 'begins-on', '2013-06-06'], ['taxotere', 'contains-1', '2013-06-06'], ['docetaxel', 'contains-1', '2013-06-20'], ['taxotere', 'contains-1', '2013-06-20'], ['docetaxel', 'contains-1', '2013-07-11'], ['taxotere', 'contains-1', '2013-07-11'], ['adriamycin', 'contains-1', '2013-08'], ['adriamycin', 'ends-on', '2013-08'], ['chemotherapy', 'ends-on', '2013-08'], ['cytoxan', 'contains-1', '2013-08'], ['cytoxan', 'ends-on', '2013-08'], ['docetaxel', 'ends-on', '2013-08'], ['taxol', 'contains-1', '2013-08'], ['docetaxel', 'ends-on', '2013-08-01'], ['taxol', 'contains-1', '2013-08-01'], ['taxol', 'ends-on', '2013-08-01'], ['taxotere', 'begins-on', '2013-08-01'], ['taxotere', 'ends-on', '2013-08-01'], ['adriamycin', 'ends-on', '2013-08-02'], ['cytoxan', 'ends-on', '2013-08-02'], ['docetaxel', 'ends-on', '2013-08-02'], ['chemotherapy', 'contains-1', '2013-08-08'], ['chemotherapy', 'contains-1', '2013-09-16']]
# Fixed timeline: [['adriamycin', 'begins-on', '2012-03'], ['cytoxan', 'begins-on', '2012-03'], ['docetaxel', 'begins-on', '2012-03'], ['adriamycin', 'contains-1', '2013-03'], ['cytoxan', 'contains-1', '2013-03'], ['adriamycin', 'begins-on', '2013-03-07'], ['cytoxan', 'begins-on', '2013-03-07'], ['adriamycin', 'contains-1', '2013-03-28'], ['cytoxan', 'contains-1', '2013-03-28'], ['adriamycin', 'contains-1', '2013-04-18'], ['cytoxan', 'contains-1', '2013-04-18'], ['adriamycin', 'begins-on', '2013-05-09'], ['adriamycin', 'ends-on', '2013-05-09'], ['cytoxan', 'begins-on', '2013-05-09'], ['cytoxan', 'ends-on', '2013-05-09'], ['docetaxel', 'ends-on', '2013-05-09'], ['docetaxel', 'begins-on', '2013-05-30'], ['taxotere', 'begins-on', '2013-05-30'], ['docetaxel', 'contains-1', '2013-06-06'], ['taxotere', 'begins-on', '2013-06-06'], ['docetaxel', 'contains-1', '2013-06-20'], ['taxotere', 'contains-1', '2013-06-20'], ['docetaxel', 'contains-1', '2013-07-11'], ['taxotere', 'contains-1', '2013-07-11'], ['adriamycin', 'ends-on', '2013-08'], ['cytoxan', 'ends-on', '2013-08'], ['docetaxel', 'ends-on', '2013-08'], ['taxol', 'contains-1', '2013-08'], ['docetaxel', 'ends-on', '2013-08-01'], ['taxol', 'ends-on', '2013-08-01'], ['taxotere', 'begins-on', '2013-08-01'], ['taxotere', 'ends-on', '2013-08-01'], ['adriamycin', 'ends-on', '2013-08-02'], ['cytoxan', 'ends-on', '2013-08-02'], ['docetaxel', 'ends-on', '2013-08-02'], ['chemotherapy', 'contains-1', '2013-08-08'], ['chemotherapy', 'contains-1', '2013-09-16']]
# Had to change timeline
# Original timeline: [['temozolomide', 'contains-1', '2011-10-28'], ['chemotherapy', 'begins-on', '2012-01-04'], ['cyclophosphamide', 'begins-on', '2012-01-04'], ['cytoxan', 'begins-on', '2012-01-04'], ['docetaxel', 'begins-on', '2012-01-04'], ['taxotere', 'begins-on', '2012-01-04'], ['tc', 'begins-on', '2012-01-04'], ['tc', 'contains-1', '2012-03'], ['cyclophosphamide', 'ends-on', '2012-03-07'], ['docetaxel', 'ends-on', '2012-03-07'], ['tc', 'ends-on', '2012-03-07'], ['cytoxan', 'ends-on', '2012-05-02'], ['taxotere', 'ends-on', '2012-05-02']]
# Fixed timeline: [['temozolomide', 'contains-1', '2011-10-28'], ['cyclophosphamide', 'begins-on', '2012-01-04'], ['cytoxan', 'begins-on', '2012-01-04'], ['docetaxel', 'begins-on', '2012-01-04'], ['taxotere', 'begins-on', '2012-01-04'], ['tc', 'begins-on', '2012-01-04'], ['tc', 'contains-1', '2012-03'], ['cyclophosphamide', 'ends-on', '2012-03-07'], ['docetaxel', 'ends-on', '2012-03-07'], ['tc', 'ends-on', '2012-03-07'], ['cytoxan', 'ends-on', '2012-05-02'], ['taxotere', 'ends-on', '2012-05-02']]
# Had to change timeline
# Original timeline: [['anastrozole', 'begins-on', '2013-09'], ['anastrozole', 'contains-1', '2013-09'], ['faslodex', 'begins-on', '2013-09'], ['faslodex', 'contains-1', '2013-09'], ['anastrozole', 'begins-on', '2013-09-06'], ['anastrozole', 'contains-1', '2013-09-06'], ['faslodex', 'contains-1', '2013-09-06'], ['anastrozole', 'begins-on', '2013-09-10'], ['faslodex', 'begins-on', '2013-09-10'], ['anastrozole', 'contains-1', '2013-09-11'], ['arimidex', 'contains-1', '2013-09-11'], ['faslodex', 'contains-1', '2013-09-11'], ['anastrozole', 'begins-on', '2013-09-13'], ['arimidex', 'contains-1', '2013-09-16'], ['arimidex', 'contains-1', '2013-09-18'], ['faslodex', 'begins-on', '2013-09-19'], ['faslodex', 'contains-1', '2013-09-19'], ['faslodex', 'contains-1', '2013-10-17'], ['faslodex', 'ends-on', '2013-11'], ['anastrozole', 'contains-1', '2014-02-24']]
# Fixed timeline: [['anastrozole', 'begins-on', '2013-09'], ['faslodex', 'begins-on', '2013-09'], ['anastrozole', 'begins-on', '2013-09-06'], ['faslodex', 'contains-1', '2013-09-06'], ['anastrozole', 'begins-on', '2013-09-10'], ['faslodex', 'begins-on', '2013-09-10'], ['anastrozole', 'contains-1', '2013-09-11'], ['arimidex', 'contains-1', '2013-09-11'], ['faslodex', 'contains-1', '2013-09-11'], ['anastrozole', 'begins-on', '2013-09-13'], ['arimidex', 'contains-1', '2013-09-16'], ['arimidex', 'contains-1', '2013-09-18'], ['faslodex', 'begins-on', '2013-09-19'], ['faslodex', 'contains-1', '2013-10-17'], ['faslodex', 'ends-on', '2013-11'], ['anastrozole', 'contains-1', '2014-02-24']]
# Had to change timeline
# Original timeline: [['tch', 'begins-on', '2013-06-09'], ['carboplatin', 'contains-1', '2013-06-11'], ['chemotherapy', 'contains-1', '2013-06-11'], ['herceptin', 'contains-1', '2013-06-11'], ['taxotere', 'contains-1', '2013-06-11'], ['chemo', 'contains-1', '2013-06-19'], ['tch', 'begins-on', '2013-06-19'], ['herceptin', 'contains-1', '2013-06-25'], ['tch', 'ends-on', '2013-08-20'], ['tch', 'contains-1', '2013-09-10'], ['carboplatin', 'ends-on', '2013-10-01'], ['herceptin', 'ends-on', '2013-10-01'], ['taxotere', 'ends-on', '2013-10-01'], ['tch', 'contains-1', '2013-10-01'], ['tch', 'ends-on', '2013-10-01'], ['herceptin', 'begins-on', '2013-10-22'], ['carboplatin', 'ends-on', '2013-10-30'], ['chemo', 'contains-1', '2013-10-30'], ['herceptin', 'ends-on', '2013-10-30'], ['taxotere', 'ends-on', '2013-10-30'], ['tch', 'contains-1', '2013-10-30'], ['tch', 'ends-on', '2013-10-30'], ['herceptin', 'contains-1', '2013-12-03'], ['femara', 'begins-on', '2013-12-10'], ['femara', 'contains-1', '2014-04-08'], ['herceptin', 'contains-1', '2014-04-08'], ['herceptin', 'contains-1', '2014-05-22']]
# Fixed timeline: [['tch', 'begins-on', '2013-06-09'], ['carboplatin', 'contains-1', '2013-06-11'], ['herceptin', 'contains-1', '2013-06-11'], ['taxotere', 'contains-1', '2013-06-11'], ['chemo', 'contains-1', '2013-06-19'], ['tch', 'begins-on', '2013-06-19'], ['herceptin', 'contains-1', '2013-06-25'], ['tch', 'ends-on', '2013-08-20'], ['tch', 'contains-1', '2013-09-10'], ['carboplatin', 'ends-on', '2013-10-01'], ['herceptin', 'ends-on', '2013-10-01'], ['taxotere', 'ends-on', '2013-10-01'], ['tch', 'ends-on', '2013-10-01'], ['herceptin', 'begins-on', '2013-10-22'], ['carboplatin', 'ends-on', '2013-10-30'], ['chemo', 'contains-1', '2013-10-30'], ['herceptin', 'ends-on', '2013-10-30'], ['taxotere', 'ends-on', '2013-10-30'], ['tch', 'ends-on', '2013-10-30'], ['herceptin', 'contains-1', '2013-12-03'], ['femara', 'begins-on', '2013-12-10'], ['femara', 'contains-1', '2014-04-08'], ['herceptin', 'contains-1', '2014-04-08'], ['herceptin', 'contains-1', '2014-05-22']]
# Had to change timeline
# Original timeline: [['chemotherapy', 'contains-1', '2007-09'], ['chemotherapy', 'contains-1', '2007-09-17'], ['herceptin', 'contains-1', '2007-09-17'], ['tc', 'begins-on', '2007-09-18'], ['tc', 'contains-1', '2007-09-18'], ['chemotherapy', 'contains-1', '2007-09-20'], ['chemotherapy', 'contains-1', '2007-10-01'], ['adriamycin', 'begins-on', '2007-10-26'], ['cyclophosphamide', 'begins-on', '2007-10-26'], ['cyclophosphamide', 'contains-1', '2007-10-26'], ['docetaxel', 'contains-1', '2007-10-26'], ['doxorubicin', 'begins-on', '2007-10-26'], ['doxorubicin', 'contains-1', '2007-10-26'], ['taxol', 'begins-on', '2007-10-26'], ['taxol', 'begins-on', '2007-11-06'], ['ac', 'begins-on', '2007-11-16'], ['ac', 'contains-1', '2007-11-16'], ['adriamycin', 'contains-1', '2007-11-16'], ['chemotherapy', 'contains-1', '2007-11-16'], ['cyclophosphamide', 'contains-1', '2007-11-16'], ['ac', 'contains-1', '2007-12-28'], ['adriamycin', 'contains-1', '2007-12-28'], ['chemotherapy', 'contains-1', '2007-12-28'], ['cyclophosphamide', 'contains-1', '2007-12-28'], ['taxol', 'begins-on', '2008-01'], ['ac', 'contains-1', '2008-01-18'], ['taxol', 'begins-on', '2008-01-18'], ['taxol', 'ends-on', '2008-03-14'], ['taxol', 'ends-on', '2008-04'], ['arimidex', 'begins-on', '2008-10-01']]
# Fixed timeline: [['chemotherapy', 'contains-1', '2007-09'], ['herceptin', 'contains-1', '2007-09-17'], ['tc', 'begins-on', '2007-09-18'], ['chemotherapy', 'contains-1', '2007-09-20'], ['chemotherapy', 'contains-1', '2007-10-01'], ['adriamycin', 'begins-on', '2007-10-26'], ['cyclophosphamide', 'begins-on', '2007-10-26'], ['docetaxel', 'contains-1', '2007-10-26'], ['doxorubicin', 'begins-on', '2007-10-26'], ['taxol', 'begins-on', '2007-10-26'], ['taxol', 'begins-on', '2007-11-06'], ['ac', 'begins-on', '2007-11-16'], ['adriamycin', 'contains-1', '2007-11-16'], ['cyclophosphamide', 'contains-1', '2007-11-16'], ['ac', 'contains-1', '2007-12-28'], ['adriamycin', 'contains-1', '2007-12-28'], ['cyclophosphamide', 'contains-1', '2007-12-28'], ['taxol', 'begins-on', '2008-01'], ['ac', 'contains-1', '2008-01-18'], ['taxol', 'begins-on', '2008-01-18'], ['taxol', 'ends-on', '2008-03-14'], ['taxol', 'ends-on', '2008-04'], ['arimidex', 'begins-on', '2008-10-01']]
# Had to change timeline
# Original timeline: [['chemotherapy', 'contains-1', '2003-12-08'], ['adriamycin', 'begins-on', '2003-12-09'], ['adriamycin', 'contains-1', '2003-12-09'], ['chemotherapy', 'begins-on', '2003-12-09'], ['cytoxan', 'begins-on', '2003-12-09'], ['cytoxan', 'contains-1', '2003-12-09'], ['taxotere', 'begins-on', '2003-12-09'], ['taxotere', 'contains-1', '2003-12-09'], ['chemotherapy', 'begins-on', '2006'], ['arimidex', 'begins-on', '2006-09-03'], ['arimidex', 'contains-1', '2006-09-03'], ['chemotherapy', 'contains-1', '2006-09-03'], ['arimidex', 'contains-1', '2006-09-28'], ['chemo', 'contains-1', '2011-02-15'], ['chemotherapy', 'contains-1', '2011-02-15']]
# Fixed timeline: [['chemotherapy', 'contains-1', '2003-12-08'], ['adriamycin', 'begins-on', '2003-12-09'], ['cytoxan', 'begins-on', '2003-12-09'], ['taxotere', 'begins-on', '2003-12-09'], ['chemotherapy', 'begins-on', '2006'], ['arimidex', 'begins-on', '2006-09-03'], ['chemotherapy', 'contains-1', '2006-09-03'], ['arimidex', 'contains-1', '2006-09-28'], ['chemotherapy', 'contains-1', '2011-02-15'], ['chemotherapy', 'contains-1', '2011-02-15']]
# Had to change timeline
# Original timeline: [['arimidex', 'begins-on', '2011-05-31'], ['arimidex', 'contains-1', '2011-05-31'], ['tc', 'contains-1', '2011-08-16'], ['anastrozole', 'contains-1', '2011-10'], ['arimidex', 'contains-1', '2011-10'], ['anastrozole', 'contains-1', '2011-10-18'], ['arimidex', 'contains-1', '2011-10-18']]
# Fixed timeline: [['arimidex', 'begins-on', '2011-05-31'], ['tc', 'contains-1', '2011-08-16'], ['anastrozole', 'contains-1', '2011-10'], ['arimidex', 'contains-1', '2011-10'], ['anastrozole', 'contains-1', '2011-10-18'], ['arimidex', 'contains-1', '2011-10-18']]
# Had to change timeline
# Original timeline: [['anastrozole', 'begins-on', '2013'], ['cyclophosphamide', 'begins-on', '2013-04-03'], ['taxotere', 'begins-on', '2013-04-03'], ['tc', 'contains-1', '2013-04-19'], ['tc', 'begins-on', '2013-05-20'], ['tc', 'contains-1', '2013-05-20'], ['anastrozole', 'begins-on', '2013-06'], ['tc', 'contains-1', '2013-06-12'], ['anastrozole', 'begins-on', '2013-09'], ['anastrozole', 'begins-on', '2013-09-01'], ['anastrozole', 'begins-on', '2013-09-16'], ['anastrozole', 'ends-on', '2014-02-03'], ['femara', 'begins-on', '2014-02-04']]
# Fixed timeline: [['anastrozole', 'begins-on', '2013'], ['cyclophosphamide', 'begins-on', '2013-04-03'], ['taxotere', 'begins-on', '2013-04-03'], ['tc', 'contains-1', '2013-04-19'], ['tc', 'begins-on', '2013-05-20'], ['anastrozole', 'begins-on', '2013-06'], ['tc', 'contains-1', '2013-06-12'], ['anastrozole', 'begins-on', '2013-09'], ['anastrozole', 'begins-on', '2013-09-01'], ['anastrozole', 'begins-on', '2013-09-16'], ['anastrozole', 'ends-on', '2014-02-03'], ['femara', 'begins-on', '2014-02-04']]
# Had to change timeline
# Original timeline: [['carboplatin', 'begins-on', '2012'], ['herceptin', 'begins-on', '2012'], ['taxotere', 'begins-on', '2012'], ['chemotherapy', 'contains-1', '2012-09-28'], ['herceptin', 'contains-1', '2012-09-28'], ['carboplatin', 'begins-on', '2012-10-01'], ['herceptin', 'begins-on', '2012-10-01'], ['taxotere', 'begins-on', '2012-10-01'], ['carboplatin', 'begins-on', '2012-10-10'], ['herceptin', 'begins-on', '2012-10-10'], ['taxotere', 'begins-on', '2012-10-10'], ['carbo', 'begins-on', '2012-10-15'], ['herceptin', 'begins-on', '2012-10-15'], ['taxol', 'begins-on', '2012-10-15'], ['taxotere', 'begins-on', '2012-10-15'], ['carboplatin', 'begins-on', '2012-11-05'], ['carboplatin', 'ends-on', '2012-11-05'], ['herceptin', 'begins-on', '2012-11-05'], ['herceptin', 'ends-on', '2012-11-05'], ['taxotere', 'begins-on', '2012-11-05'], ['taxotere', 'ends-on', '2012-11-05'], ['carbo', 'begins-on', '2012-11-26'], ['chemotherapy', 'begins-on', '2012-11-26'], ['zometa', 'begins-on', '2012-11-26'], ['chemotherapy', 'begins-on', '2012-12-17'], ['zometa', 'contains-1', '2012-12-17'], ['carbo', 'ends-on', '2013-01'], ['carboplatin', 'begins-on', '2013-01'], ['carboplatin', 'ends-on', '2013-01'], ['chemotherapy', 'ends-on', '2013-01'], ['herceptin', 'begins-on', '2013-01'], ['herceptin', 'ends-on', '2013-01'], ['taxotere', 'begins-on', '2013-01'], ['taxotere', 'ends-on', '2013-01'], ['carboplatin', 'contains-1', '2013-01-08'], ['herceptin', 'contains-1', '2013-01-08'], ['taxotere', 'contains-1', '2013-01-08'], ['zometa', 'contains-1', '2013-01-08'], ['carboplatin', 'ends-on', '2013-01-31'], ['herceptin', 'ends-on', '2013-01-31'], ['taxotere', 'ends-on', '2013-01-31'], ['chemotherapy', 'ends-on', '2013-02'], ['zometa', 'begins-on', '2013-02'], ['carboplatin', 'contains-1', '2013-02-07'], ['herceptin', 'contains-1', '2013-02-07'], ['taxotere', 'contains-1', '2013-02-07'], ['zometa', 'begins-on', '2013-02-11'], ['zometa', 'contains-1', '2013-02-11'], ['chemotherapy', 'ends-on', '2013-02-20'], ['carboplatin', 'contains-1', '2013-02-21'], ['herceptin', 'contains-1', '2013-02-21'], ['taxotere', 'contains-1', '2013-02-21'], ['zometa', 'contains-1', '2013-02-21'], ['arimidex', 'begins-on', '2013-03-21'], ['arimidex', 'begins-on', '2013-03-28'], ['arimidex', 'begins-on', '2013-04'], ['zometa', 'begins-on', '2013-04-08'], ['chemotherapy', 'ends-on', '2013-06-07'], ['zometa', 'contains-1', '2013-06-07'], ['herceptin', 'contains-1', '2013-09'], ['zometa', 'contains-1', '2013-10-15'], ['zometa', 'contains-1', '2013-10-17'], ['zometa', 'begins-on', '2014'], ['faslodex', 'begins-on', '2014-01'], ['faslodex', 'contains-1', '2014-02-05'], ['zometa', 'contains-1', '2014-02-05'], ['faslodex', 'begins-on', '2014-04-09'], ['zometa', 'begins-on', '2014-04-09'], ['faslodex', 'begins-on', '2014-06-06'], ['zometa', 'begins-on', '2014-06-06'], ['faslodex', 'contains-1', '2014-07-07'], ['zometa', 'contains-1', '2014-07-07'], ['faslodex', 'begins-on', '2014-08-11'], ['zometa', 'begins-on', '2014-08-11'], ['faslodex', 'contains-1', '2014-09-30'], ['zometa', 'contains-1', '2014-09-30'], ['kadcyla', 'begins-on', '2014-10-21'], ['kadcyla', 'contains-1', '2014-11-07']]
# Fixed timeline: [['carboplatin', 'begins-on', '2012'], ['herceptin', 'begins-on', '2012'], ['taxotere', 'begins-on', '2012'], ['herceptin', 'contains-1', '2012-09-28'], ['carboplatin', 'begins-on', '2012-10-01'], ['herceptin', 'begins-on', '2012-10-01'], ['taxotere', 'begins-on', '2012-10-01'], ['carboplatin', 'begins-on', '2012-10-10'], ['herceptin', 'begins-on', '2012-10-10'], ['taxotere', 'begins-on', '2012-10-10'], ['carbo', 'begins-on', '2012-10-15'], ['herceptin', 'begins-on', '2012-10-15'], ['taxol', 'begins-on', '2012-10-15'], ['taxotere', 'begins-on', '2012-10-15'], ['carboplatin', 'begins-on', '2012-11-05'], ['carboplatin', 'ends-on', '2012-11-05'], ['herceptin', 'begins-on', '2012-11-05'], ['herceptin', 'ends-on', '2012-11-05'], ['taxotere', 'begins-on', '2012-11-05'], ['taxotere', 'ends-on', '2012-11-05'], ['carbo', 'begins-on', '2012-11-26'], ['zometa', 'begins-on', '2012-11-26'], ['chemotherapy', 'begins-on', '2012-12-17'], ['zometa', 'contains-1', '2012-12-17'], ['carbo', 'ends-on', '2013-01'], ['carboplatin', 'begins-on', '2013-01'], ['carboplatin', 'ends-on', '2013-01'], ['herceptin', 'begins-on', '2013-01'], ['herceptin', 'ends-on', '2013-01'], ['taxotere', 'begins-on', '2013-01'], ['taxotere', 'ends-on', '2013-01'], ['carboplatin', 'contains-1', '2013-01-08'], ['herceptin', 'contains-1', '2013-01-08'], ['taxotere', 'contains-1', '2013-01-08'], ['zometa', 'contains-1', '2013-01-08'], ['carboplatin', 'ends-on', '2013-01-31'], ['herceptin', 'ends-on', '2013-01-31'], ['taxotere', 'ends-on', '2013-01-31'], ['chemotherapy', 'ends-on', '2013-02'], ['zometa', 'begins-on', '2013-02'], ['carboplatin', 'contains-1', '2013-02-07'], ['herceptin', 'contains-1', '2013-02-07'], ['taxotere', 'contains-1', '2013-02-07'], ['zometa', 'begins-on', '2013-02-11'], ['chemotherapy', 'ends-on', '2013-02-20'], ['carboplatin', 'contains-1', '2013-02-21'], ['herceptin', 'contains-1', '2013-02-21'], ['taxotere', 'contains-1', '2013-02-21'], ['zometa', 'contains-1', '2013-02-21'], ['arimidex', 'begins-on', '2013-03-21'], ['arimidex', 'begins-on', '2013-03-28'], ['arimidex', 'begins-on', '2013-04'], ['zometa', 'begins-on', '2013-04-08'], ['chemotherapy', 'ends-on', '2013-06-07'], ['zometa', 'contains-1', '2013-06-07'], ['herceptin', 'contains-1', '2013-09'], ['zometa', 'contains-1', '2013-10-15'], ['zometa', 'contains-1', '2013-10-17'], ['zometa', 'begins-on', '2014'], ['faslodex', 'begins-on', '2014-01'], ['faslodex', 'contains-1', '2014-02-05'], ['zometa', 'contains-1', '2014-02-05'], ['faslodex', 'begins-on', '2014-04-09'], ['zometa', 'begins-on', '2014-04-09'], ['faslodex', 'begins-on', '2014-06-06'], ['zometa', 'begins-on', '2014-06-06'], ['faslodex', 'contains-1', '2014-07-07'], ['zometa', 'contains-1', '2014-07-07'], ['faslodex', 'begins-on', '2014-08-11'], ['zometa', 'begins-on', '2014-08-11'], ['faslodex', 'contains-1', '2014-09-30'], ['zometa', 'contains-1', '2014-09-30'], ['kadcyla', 'begins-on', '2014-10-21'], ['kadcyla', 'contains-1', '2014-11-07']]
# Had to change timeline
# Original timeline: [['adriamycin', 'begins-on', '2011'], ['adriamycin', 'contains-1', '2011'], ['chemotherapy', 'begins-on', '2011'], ['cyclophosphamide', 'contains-1', '2011'], ['cytoxan', 'begins-on', '2011'], ['taxotere', 'begins-on', '2011'], ['taxotere', 'contains-1', '2011'], ['adriamycin', 'begins-on', '2011-06'], ['chemotherapy', 'begins-on', '2011-06'], ['taxotere', 'begins-on', '2011-06'], ['adriamycin', 'begins-on', '2011-08'], ['chemotherapy', 'begins-on', '2011-08'], ['cyclophosphamide', 'begins-on', '2011-08'], ['cytoxan', 'begins-on', '2011-08'], ['taxotere', 'begins-on', '2011-08-05'], ['adriamycin', 'begins-on', '2011-08-06'], ['cyclophosphamide', 'begins-on', '2011-08-06'], ['cytoxan', 'begins-on', '2011-08-06'], ['taxotere', 'begins-on', '2011-08-06'], ['taxotere', 'begins-on', '2011-09'], ['adriamycin', 'contains-1', '2011-10'], ['cytoxan', 'contains-1', '2011-10'], ['taxotere', 'begins-on', '2011-10-03'], ['adriamycin', 'contains-1', '2011-12'], ['adriamycin', 'ends-on', '2011-12'], ['chemotherapy', 'contains-1', '2011-12'], ['chemotherapy', 'ends-on', '2011-12'], ['cytoxan', 'contains-1', '2011-12'], ['cytoxan', 'ends-on', '2011-12'], ['taxotere', 'begins-on', '2011-12'], ['taxotere', 'contains-1', '2011-12'], ['taxotere', 'ends-on', '2011-12'], ['cyclophosphamide', 'ends-on', '2011-12-15'], ['taxotere', 'ends-on', '2011-12-15'], ['adriamycin', 'contains-1', '2012'], ['chemotherapy', 'contains-1', '2012'], ['cyclophosphamide', 'contains-1', '2012'], ['cytoxan', 'contains-1', '2012'], ['taxotere', 'contains-1', '2012'], ['adriamycin', 'begins-on', '2012-01'], ['cytoxan', 'begins-on', '2012-01'], ['taxotere', 'begins-on', '2012-01'], ['adriamycin', 'ends-on', '2012-01-05'], ['chemotherapy', 'ends-on', '2012-01-05'], ['cisplatin', 'ends-on', '2012-01-05'], ['cytoxan', 'ends-on', '2012-01-05'], ['taxotere', 'ends-on', '2012-01-05'], ['adriamycin', 'begins-on', '2012-02-01']]
# Fixed timeline: [['adriamycin', 'begins-on', '2011'], ['cyclophosphamide', 'contains-1', '2011'], ['cytoxan', 'begins-on', '2011'], ['taxotere', 'begins-on', '2011'], ['adriamycin', 'begins-on', '2011-06'], ['taxotere', 'begins-on', '2011-06'], ['adriamycin', 'begins-on', '2011-08'], ['cyclophosphamide', 'begins-on', '2011-08'], ['cytoxan', 'begins-on', '2011-08'], ['taxotere', 'begins-on', '2011-08-05'], ['adriamycin', 'begins-on', '2011-08-06'], ['cyclophosphamide', 'begins-on', '2011-08-06'], ['cytoxan', 'begins-on', '2011-08-06'], ['taxotere', 'begins-on', '2011-08-06'], ['taxotere', 'begins-on', '2011-09'], ['adriamycin', 'contains-1', '2011-10'], ['cytoxan', 'contains-1', '2011-10'], ['taxotere', 'begins-on', '2011-10-03'], ['adriamycin', 'ends-on', '2011-12'], ['cytoxan', 'ends-on', '2011-12'], ['taxotere', 'begins-on', '2011-12'], ['taxotere', 'ends-on', '2011-12'], ['cyclophosphamide', 'ends-on', '2011-12-15'], ['taxotere', 'ends-on', '2011-12-15'], ['adriamycin', 'contains-1', '2012'], ['cyclophosphamide', 'contains-1', '2012'], ['cytoxan', 'contains-1', '2012'], ['taxotere', 'contains-1', '2012'], ['adriamycin', 'begins-on', '2012-01'], ['cytoxan', 'begins-on', '2012-01'], ['taxotere', 'begins-on', '2012-01'], ['adriamycin', 'ends-on', '2012-01-05'], ['cisplatin', 'ends-on', '2012-01-05'], ['cytoxan', 'ends-on', '2012-01-05'], ['taxotere', 'ends-on', '2012-01-05'], ['adriamycin', 'begins-on', '2012-02-01']]
# Had to change timeline
# Original timeline: [['carbo', 'begins-on', '2009'], ['carboplatin', 'begins-on', '2009'], ['chemotherapy', 'begins-on', '2009'], ['taxol', 'begins-on', '2009'], ['avastin', 'contains-1', '2010'], ['avastin', 'begins-on', '2010-04'], ['avastin', 'contains-1', '2010-04'], ['avastin', 'begins-on', '2010-04-11'], ['avastin', 'contains-1', '2010-04-11'], ['avastin', 'contains-1', '2010-05'], ['avastin', 'ends-on', '2010-05'], ['carboplatin', 'ends-on', '2010-05'], ['taxol', 'ends-on', '2010-05'], ['avastin', 'contains-1', '2010-11'], ['bevacizumab', 'begins-on', '2011'], ['carbo', 'begins-on', '2011'], ['cisplatin', 'begins-on', '2011'], ['gemzar', 'begins-on', '2011'], ['taxol', 'begins-on', '2011'], ['avastin', 'contains-1', '2011-04'], ['avastin', 'ends-on', '2011-04'], ['taxol', 'begins-on', '2011-04'], ['avastin', 'contains-1', '2011-04-11'], ['avastin', 'contains-1', '2011-05'], ['chemotherapy', 'begins-on', '2011-05'], ['docetaxel', 'begins-on', '2011-06'], ['taxol', 'begins-on', '2011-06'], ['chemo', 'contains-1', '2011-08-10'], ['cisplatin', 'begins-on', '2011-08-17'], ['cisplatin', 'contains-1', '2011-08-17'], ['gemzar', 'begins-on', '2011-08-17'], ['gemzar', 'contains-1', '2011-08-17'], ['taxol', 'begins-on', '2011-08-31'], ['taxol', 'begins-on', '2011-09-21'], ['taxol', 'begins-on', '2011-10-12'], ['chemotherapy', 'contains-1', '2011-11-02'], ['taxol', 'begins-on', '2011-12-14'], ['chemo', 'begins-on', '2011-12-18'], ['carboplatin', 'contains-1', '2012'], ['chemo', 'contains-1', '2012'], ['docetaxel', 'begins-on', '2012-01'], ['taxol', 'begins-on', '2012-01'], ['taxol', 'ends-on', '2012-01'], ['avastin', 'ends-on', '2012-01-04'], ['chemo', 'begins-on', '2012-01-04'], ['chemo', 'contains-1', '2012-01-04'], ['taxol', 'begins-on', '2012-01-04'], ['taxol', 'contains-1', '2012-01-04'], ['taxol', 'ends-on', '2012-01-04'], ['bevacizumab', 'begins-on', '2012-02'], ['chemotherapy', 'begins-on', '2012-02-03'], ['taxol', 'begins-on', '2012-02-06'], ['chemotherapy', 'begins-on', '2012-02-07'], ['chemotherapy', 'begins-on', '2012-02-10'], ['avastin', 'begins-on', '2012-03-02'], ['bevacizumab', 'begins-on', '2012-03-16'], ['chemotherapy', 'begins-on', '2012-03-16'], ['bevacizumab', 'begins-on', '2012-03-28'], ['bevacizumab', 'ends-on', '2012-04'], ['chemo', 'contains-1', '2012-04'], ['docetaxel', 'ends-on', '2012-04'], ['doxil', 'begins-on', '2012-04'], ['avastin', 'begins-on', '2012-04-11'], ['avastin', 'contains-1', '2012-04-11'], ['chemo', 'contains-1', '2012-04-11'], ['chemotherapy', 'contains-1', '2012-04-11'], ['chemo', 'contains-1', '2012-04-12'], ['doxil', 'begins-on', '2012-05'], ['chemotherapy', 'contains-1', '2012-w21'], ['doxorubicin', 'begins-on', '2012-05-22'], ['chemo', 'contains-1', '2012-05-28'], ['doxorubicin', 'contains-1', '2012-05-28'], ['chemotherapy', 'contains-1', '2012-06-19'], ['chemotherapy', 'contains-1', '2012-07-27'], ['doxil', 'ends-on', '2012-08'], ['carbo', 'contains-1', '2012-09'], ['chemotherapy', 'begins-on', '2012-09-07'], ['carbo', 'contains-1', '2012-09-28'], ['carboplatin', 'begins-on', '2012-09-28'], ['chemotherapy', 'begins-on', '2012-09-28'], ['chemotherapy', 'contains-1', '2012-09-28'], ['zometa', 'begins-on', '2012-10-15'], ['zometa', 'contains-1', '2012-10-15'], ['zometa', 'contains-1', '2012-10-17']]
# Fixed timeline: [['carbo', 'begins-on', '2009'], ['carboplatin', 'begins-on', '2009'], ['taxol', 'begins-on', '2009'], ['avastin', 'contains-1', '2010'], ['avastin', 'begins-on', '2010-04'], ['avastin', 'begins-on', '2010-04-11'], ['avastin', 'ends-on', '2010-05'], ['carboplatin', 'ends-on', '2010-05'], ['taxol', 'ends-on', '2010-05'], ['avastin', 'contains-1', '2010-11'], ['bevacizumab', 'begins-on', '2011'], ['carbo', 'begins-on', '2011'], ['cisplatin', 'begins-on', '2011'], ['gemzar', 'begins-on', '2011'], ['taxol', 'begins-on', '2011'], ['avastin', 'ends-on', '2011-04'], ['taxol', 'begins-on', '2011-04'], ['avastin', 'contains-1', '2011-04-11'], ['avastin', 'contains-1', '2011-05'], ['chemotherapy', 'begins-on', '2011-05'], ['docetaxel', 'begins-on', '2011-06'], ['taxol', 'begins-on', '2011-06'], ['chemotherapy', 'contains-1', '2011-08-10'], ['cisplatin', 'begins-on', '2011-08-17'], ['gemzar', 'begins-on', '2011-08-17'], ['taxol', 'begins-on', '2011-08-31'], ['taxol', 'begins-on', '2011-09-21'], ['taxol', 'begins-on', '2011-10-12'], ['chemotherapy', 'contains-1', '2011-11-02'], ['taxol', 'begins-on', '2011-12-14'], ['chemotherapy', 'begins-on', '2011-12-18'], ['carboplatin', 'contains-1', '2012'], ['docetaxel', 'begins-on', '2012-01'], ['taxol', 'begins-on', '2012-01'], ['taxol', 'ends-on', '2012-01'], ['avastin', 'ends-on', '2012-01-04'], ['taxol', 'begins-on', '2012-01-04'], ['taxol', 'ends-on', '2012-01-04'], ['bevacizumab', 'begins-on', '2012-02'], ['chemotherapy', 'begins-on', '2012-02-03'], ['taxol', 'begins-on', '2012-02-06'], ['chemotherapy', 'begins-on', '2012-02-07'], ['chemotherapy', 'begins-on', '2012-02-10'], ['avastin', 'begins-on', '2012-03-02'], ['bevacizumab', 'begins-on', '2012-03-16'], ['bevacizumab', 'begins-on', '2012-03-28'], ['bevacizumab', 'ends-on', '2012-04'], ['chemotherapy', 'contains-1', '2012-04'], ['docetaxel', 'ends-on', '2012-04'], ['doxil', 'begins-on', '2012-04'], ['avastin', 'begins-on', '2012-04-11'], ['chemotherapy', 'contains-1', '2012-04-11'], ['chemotherapy', 'contains-1', '2012-04-11'], ['chemotherapy', 'contains-1', '2012-04-12'], ['doxil', 'begins-on', '2012-05'], ['chemotherapy', 'contains-1', '2012-w21'], ['doxorubicin', 'begins-on', '2012-05-22'], ['doxorubicin', 'contains-1', '2012-05-28'], ['chemotherapy', 'contains-1', '2012-06-19'], ['chemotherapy', 'contains-1', '2012-07-27'], ['doxil', 'ends-on', '2012-08'], ['carbo', 'contains-1', '2012-09'], ['chemotherapy', 'begins-on', '2012-09-07'], ['carbo', 'contains-1', '2012-09-28'], ['carboplatin', 'begins-on', '2012-09-28'], ['zometa', 'begins-on', '2012-10-15'], ['zometa', 'contains-1', '2012-10-17']]
# Had to change timeline
# Original timeline: [['carboplatin', 'begins-on', '2009-11-18'], ['paclitaxel', 'begins-on', '2009-11-18'], ['carboplatin', 'begins-on', '2010-01'], ['taxol', 'begins-on', '2010-01'], ['chemotherapy', 'ends-on', '2010-04'], ['chemotherapy', 'ends-on', '2010-05'], ['chemotherapy', 'begins-on', '2010-06'], ['cytoxan', 'contains-1', '2011-08-29'], ['taxotere', 'contains-1', '2011-08-29'], ['chemotherapy', 'contains-1', '2011-11-18'], ['chemo', 'contains-1', '2012'], ['chemotherapy', 'contains-1', '2012'], ['carboplatin', 'begins-on', '2012-05-30'], ['taxol', 'begins-on', '2012-05-30'], ['chemotherapy', 'contains-1', '2012-06-15'], ['chemotherapy', 'begins-on', '2012-07-02'], ['doxil', 'begins-on', '2012-07-15'], ['carboplatin', 'begins-on', '2012-07-18'], ['doxil', 'begins-on', '2012-07-18'], ['carboplatin', 'begins-on', '2012-08-07'], ['doxil', 'begins-on', '2012-08-07'], ['carboplatin', 'begins-on', '2012-08-15'], ['doxil', 'begins-on', '2012-08-15'], ['chemo', 'begins-on', '2012-08-18'], ['chemo', 'contains-1', '2012-09-10'], ['chemo', 'begins-on', '2012-09-12'], ['carboplatin', 'begins-on', '2012-10-10'], ['chemo', 'contains-1', '2012-10-10'], ['doxil', 'begins-on', '2012-10-10'], ['carboplatin', 'contains-1', '2012-11-01'], ['doxil', 'contains-1', '2012-11-01'], ['carboplatin', 'contains-1', '2012-11-07'], ['doxil', 'contains-1', '2012-11-07'], ['carboplatin', 'contains-1', '2012-12-05'], ['doxil', 'contains-1', '2012-12-05']]
# Fixed timeline: [['carboplatin', 'begins-on', '2009-11-18'], ['paclitaxel', 'begins-on', '2009-11-18'], ['carboplatin', 'begins-on', '2010-01'], ['taxol', 'begins-on', '2010-01'], ['chemotherapy', 'ends-on', '2010-04'], ['chemotherapy', 'ends-on', '2010-05'], ['chemotherapy', 'begins-on', '2010-06'], ['cytoxan', 'contains-1', '2011-08-29'], ['taxotere', 'contains-1', '2011-08-29'], ['chemotherapy', 'contains-1', '2011-11-18'], ['chemotherapy', 'contains-1', '2012'], ['chemotherapy', 'contains-1', '2012'], ['carboplatin', 'begins-on', '2012-05-30'], ['taxol', 'begins-on', '2012-05-30'], ['chemotherapy', 'contains-1', '2012-06-15'], ['chemotherapy', 'begins-on', '2012-07-02'], ['doxil', 'begins-on', '2012-07-15'], ['carboplatin', 'begins-on', '2012-07-18'], ['doxil', 'begins-on', '2012-07-18'], ['carboplatin', 'begins-on', '2012-08-07'], ['doxil', 'begins-on', '2012-08-07'], ['carboplatin', 'begins-on', '2012-08-15'], ['doxil', 'begins-on', '2012-08-15'], ['chemotherapy', 'begins-on', '2012-08-18'], ['chemotherapy', 'contains-1', '2012-09-10'], ['chemotherapy', 'begins-on', '2012-09-12'], ['carboplatin', 'begins-on', '2012-10-10'], ['chemotherapy', 'contains-1', '2012-10-10'], ['doxil', 'begins-on', '2012-10-10'], ['carboplatin', 'contains-1', '2012-11-01'], ['doxil', 'contains-1', '2012-11-01'], ['carboplatin', 'contains-1', '2012-11-07'], ['doxil', 'contains-1', '2012-11-07'], ['carboplatin', 'contains-1', '2012-12-05'], ['doxil', 'contains-1', '2012-12-05']]
# Had to change timeline
# Original timeline: [['carboplatin', 'contains-1', '2013'], ['chemotherapy', 'contains-1', '2013'], ['taxotere', 'contains-1', '2013'], ['carbo', 'begins-on', '2013-01-01'], ['taxol', 'begins-on', '2013-01-01'], ['carboplatin', 'begins-on', '2013-01-03'], ['chemotherapy', 'begins-on', '2013-01-03'], ['taxotere', 'begins-on', '2013-01-03'], ['chemotherapy', 'begins-on', '2013-01-24'], ['chemotherapy', 'ends-on', '2013-01-24'], ['tc', 'begins-on', '2013-01-24'], ['tc', 'ends-on', '2013-01-24'], ['chemotherapy', 'begins-on', '2013-01-31'], ['carbo', 'contains-1', '2013-02-21'], ['taxol', 'contains-1', '2013-02-21'], ['taxotere', 'begins-on', '2013-02-21'], ['carbo', 'contains-1', '2013-03-14'], ['chemotherapy', 'contains-1', '2013-03-14'], ['taxol', 'contains-1', '2013-03-14'], ['taxotere', 'contains-1', '2013-03-14'], ['chemotherapy', 'contains-1', '2013-04'], ['carbo', 'contains-1', '2013-04-04'], ['taxotere', 'contains-1', '2013-04-04'], ['chemotherapy', 'contains-1', '2013-04-12'], ['carbo', 'contains-1', '2013-04-25'], ['chemo', 'contains-1', '2013-04-25'], ['chemotherapy', 'contains-1', '2013-04-25'], ['taxotere', 'contains-1', '2013-04-25'], ['carboplatin', 'begins-on', '2013-05-31'], ['chemo', 'begins-on', '2013-05-31'], ['chemotherapy', 'begins-on', '2013-05-31'], ['chemotherapy', 'contains-1', '2013-05-31'], ['taxotere', 'begins-on', '2013-05-31'], ['gemzar', 'begins-on', '2013-06-01'], ['chemotherapy', 'contains-1', '2013-06-06'], ['chemotherapy', 'contains-1', '2013-06-13'], ['chemotherapy', 'begins-on', '2013-06-21']]
# Fixed timeline: [['carboplatin', 'contains-1', '2013'], ['taxotere', 'contains-1', '2013'], ['carbo', 'begins-on', '2013-01-01'], ['taxol', 'begins-on', '2013-01-01'], ['carboplatin', 'begins-on', '2013-01-03'], ['taxotere', 'begins-on', '2013-01-03'], ['tc', 'begins-on', '2013-01-24'], ['tc', 'ends-on', '2013-01-24'], ['chemotherapy', 'begins-on', '2013-01-31'], ['carbo', 'contains-1', '2013-02-21'], ['taxol', 'contains-1', '2013-02-21'], ['taxotere', 'begins-on', '2013-02-21'], ['carbo', 'contains-1', '2013-03-14'], ['taxol', 'contains-1', '2013-03-14'], ['taxotere', 'contains-1', '2013-03-14'], ['chemotherapy', 'contains-1', '2013-04'], ['carbo', 'contains-1', '2013-04-04'], ['taxotere', 'contains-1', '2013-04-04'], ['chemotherapy', 'contains-1', '2013-04-12'], ['carbo', 'contains-1', '2013-04-25'], ['taxotere', 'contains-1', '2013-04-25'], ['carboplatin', 'begins-on', '2013-05-31'], ['taxotere', 'begins-on', '2013-05-31'], ['gemzar', 'begins-on', '2013-06-01'], ['chemotherapy', 'contains-1', '2013-06-06'], ['chemotherapy', 'contains-1', '2013-06-13'], ['chemotherapy', 'begins-on', '2013-06-21']]
# Had to change timeline
# Original timeline: [['chemotherapy', 'contains-1', '2012'], ['carboplatin', 'begins-on', '2013-01-17'], ['chemotherapy', 'begins-on', '2013-01-17'], ['paclitaxel', 'begins-on', '2013-01-17'], ['carboplatin', 'begins-on', '2013-02-27'], ['taxol', 'begins-on', '2013-02-27'], ['carboplatin', 'contains-1', '2013-03-20'], ['taxol', 'contains-1', '2013-03-20'], ['carboplatin', 'begins-on', '2013-04-10'], ['chemotherapy', 'begins-on', '2013-04-10'], ['taxotere', 'begins-on', '2013-04-10'], ['carboplatin', 'contains-1', '2013-05'], ['chemotherapy', 'contains-1', '2013-05'], ['taxol', 'contains-1', '2013-05'], ['tc', 'contains-1', '2013-05'], ['carboplatin', 'contains-1', '2013-06-05'], ['paclitaxel', 'contains-1', '2013-06-05'], ['chemotherapy', 'ends-on', '2013-06-19'], ['carboplatin', 'contains-1', '2013-07'], ['taxol', 'contains-1', '2013-07']]
# Fixed timeline: [['chemotherapy', 'contains-1', '2012'], ['carboplatin', 'begins-on', '2013-01-17'], ['paclitaxel', 'begins-on', '2013-01-17'], ['carboplatin', 'begins-on', '2013-02-27'], ['taxol', 'begins-on', '2013-02-27'], ['carboplatin', 'contains-1', '2013-03-20'], ['taxol', 'contains-1', '2013-03-20'], ['carboplatin', 'begins-on', '2013-04-10'], ['taxotere', 'begins-on', '2013-04-10'], ['carboplatin', 'contains-1', '2013-05'], ['taxol', 'contains-1', '2013-05'], ['tc', 'contains-1', '2013-05'], ['carboplatin', 'contains-1', '2013-06-05'], ['paclitaxel', 'contains-1', '2013-06-05'], ['chemotherapy', 'ends-on', '2013-06-19'], ['carboplatin', 'contains-1', '2013-07'], ['taxol', 'contains-1', '2013-07']]
# Had to change timeline
# Original timeline: [['chemotherapy', 'begins-on', '2012'], ['chemotherapy', 'contains-1', '2013-02-15'], ['zelboraf', 'begins-on', '2013-03-21'], ['zelboraf', 'begins-on', '2013-03-23'], ['zelboraf', 'begins-on', '2013-03-27'], ['zelboraf', 'contains-1', '2013-03-27'], ['zelboraf', 'ends-on', '2013-03-28'], ['chemotherapy', 'contains-1', '2013-04-01'], ['chemotherapy', 'contains-1', '2013-04-04'], ['zelboraf', 'begins-on', '2013-04-09'], ['zelboraf', 'begins-on', '2013-04-15'], ['zelboraf', 'begins-on', '2013-04-17'], ['zelboraf', 'contains-1', '2013-04-18'], ['chemotherapy', 'begins-on', '2013-04-19'], ['chemotherapy', 'contains-1', '2013-04-19'], ['zelboraf', 'begins-on', '2013-04-19'], ['zelboraf', 'ends-on', '2013-05-09'], ['zelboraf', 'ends-on', '2013-05-21'], ['ipilimumab', 'begins-on', '2013-06-04'], ['ipilimumab', 'contains-1', '2013-06-24'], ['ipilimumab', 'begins-on', '2013-06-25'], ['chemotherapy', 'contains-1', '2013-06-27']]
# Fixed timeline: [['chemotherapy', 'begins-on', '2012'], ['chemotherapy', 'contains-1', '2013-02-15'], ['zelboraf', 'begins-on', '2013-03-21'], ['zelboraf', 'begins-on', '2013-03-23'], ['zelboraf', 'begins-on', '2013-03-27'], ['zelboraf', 'ends-on', '2013-03-28'], ['chemotherapy', 'contains-1', '2013-04-01'], ['chemotherapy', 'contains-1', '2013-04-04'], ['zelboraf', 'begins-on', '2013-04-09'], ['zelboraf', 'begins-on', '2013-04-15'], ['zelboraf', 'begins-on', '2013-04-17'], ['zelboraf', 'contains-1', '2013-04-18'], ['zelboraf', 'begins-on', '2013-04-19'], ['zelboraf', 'ends-on', '2013-05-09'], ['zelboraf', 'ends-on', '2013-05-21'], ['ipilimumab', 'begins-on', '2013-06-04'], ['ipilimumab', 'contains-1', '2013-06-24'], ['ipilimumab', 'begins-on', '2013-06-25'], ['chemotherapy', 'contains-1', '2013-06-27']]
# Had to change timeline
# Original timeline: [['chemotherapy', 'begins-on', '2010-07-26'], ['interleukin-2', 'begins-on', '2010-07-26'], ['interleukin-2', 'begins-on', '2010-07-27'], ['chemotherapy', 'contains-1', '2010-07-29'], ['interleukin-2', 'begins-on', '2010-07-30'], ['interleukin-2', 'begins-on', '2010-11-22'], ['interleukin-2', 'contains-1', '2010-11-27'], ['interleukin-2', 'begins-on', '2010-12-13'], ['interleukin-2', 'contains-1', '2010-12-19'], ['interleukin-2', 'begins-on', '2011-01-10'], ['interleukin-2', 'contains-1', '2011-01-15'], ['interleukin-2', 'begins-on', '2011-02-28'], ['interleukin-2', 'contains-1', '2011-02-28'], ['interleukin-2', 'contains-1', '2011-03-02'], ['interleukin-2', 'contains-1', '2011-03-04']]
# Fixed timeline: [['interleukin-2', 'begins-on', '2010-07-26'], ['interleukin-2', 'begins-on', '2010-07-27'], ['chemotherapy', 'contains-1', '2010-07-29'], ['interleukin-2', 'begins-on', '2010-07-30'], ['interleukin-2', 'begins-on', '2010-11-22'], ['interleukin-2', 'contains-1', '2010-11-27'], ['interleukin-2', 'begins-on', '2010-12-13'], ['interleukin-2', 'contains-1', '2010-12-19'], ['interleukin-2', 'begins-on', '2011-01-10'], ['interleukin-2', 'contains-1', '2011-01-15'], ['interleukin-2', 'begins-on', '2011-02-28'], ['interleukin-2', 'contains-1', '2011-03-02'], ['interleukin-2', 'contains-1', '2011-03-04']]
# Had to change timeline
# Original timeline: [['alfa-2b interferon', 'contains-1', '2013'], ['interferon', 'contains-1', '2013'], ['ipilimumab', 'contains-1', '2013'], ['interferon', 'contains-1', '2013-w41'], ['ipilimumab', 'contains-1', '2013-w41'], ['alfa-2b interferon', 'contains-1', '2013-07'], ['interferon', 'contains-1', '2013-07'], ['interleukin-2', 'contains-1', '2013-07'], ['ipilimumab', 'contains-1', '2013-07'], ['interferon', 'begins-on', '2013-07-14'], ['ipilimumab', 'begins-on', '2013-07-14'], ['alfa-2b interferon', 'contains-1', '2013-08'], ['ipilimumab', 'contains-1', '2013-08'], ['alfa-2b interferon', 'contains-1', '2013-08-05'], ['ipilimumab', 'contains-1', '2013-08-05'], ['alfa-2b interferon', 'begins-on', '2013-08-12'], ['ipilimumab', 'begins-on', '2013-08-12'], ['alfa-2b interferon', 'ends-on', '2013-08-23'], ['alfa-2b interferon', 'ends-on', '2013-08-26'], ['ipilimumab', 'begins-on', '2013-09-15'], ['interferon', 'begins-on', '2013-09-16'], ['alfa-2b interferon', 'contains-1', '2013-10'], ['ipilimumab', 'contains-1', '2013-10'], ['interferon', 'begins-on', '2013-10-05'], ['ipilimumab', 'begins-on', '2013-10-05'], ['alfa-2b interferon', 'contains-1', '2013-10-07'], ['interferon', 'contains-1', '2013-10-07'], ['ipilimumab', 'contains-1', '2013-10-07'], ['interferon', 'contains-1', '2013-10-08'], ['ipilimumab', 'contains-1', '2013-10-08'], ['alfa-2b interferon', 'contains-1', '2013-10-09'], ['interferon', 'contains-1', '2013-10-09'], ['interferon', 'ends-on', '2013-10-09'], ['ipilimumab', 'contains-1', '2013-10-09'], ['ipilimumab', 'ends-on', '2013-10-09'], ['ipilimumab', 'ends-on', '2013-10-22'], ['alfa-2b interferon', 'begins-on', '2013-11-06'], ['interferon', 'begins-on', '2013-11-06'], ['ipilimumab', 'begins-on', '2013-11-06']]
# Fixed timeline: [['alfa-2b interferon', 'contains-1', '2013'], ['interferon', 'contains-1', '2013'], ['ipilimumab', 'contains-1', '2013'], ['interferon', 'contains-1', '2013-w41'], ['ipilimumab', 'contains-1', '2013-w41'], ['alfa-2b interferon', 'contains-1', '2013-07'], ['interferon', 'contains-1', '2013-07'], ['interleukin-2', 'contains-1', '2013-07'], ['ipilimumab', 'contains-1', '2013-07'], ['interferon', 'begins-on', '2013-07-14'], ['ipilimumab', 'begins-on', '2013-07-14'], ['alfa-2b interferon', 'contains-1', '2013-08'], ['ipilimumab', 'contains-1', '2013-08'], ['alfa-2b interferon', 'contains-1', '2013-08-05'], ['ipilimumab', 'contains-1', '2013-08-05'], ['alfa-2b interferon', 'begins-on', '2013-08-12'], ['ipilimumab', 'begins-on', '2013-08-12'], ['alfa-2b interferon', 'ends-on', '2013-08-23'], ['alfa-2b interferon', 'ends-on', '2013-08-26'], ['ipilimumab', 'begins-on', '2013-09-15'], ['interferon', 'begins-on', '2013-09-16'], ['alfa-2b interferon', 'contains-1', '2013-10'], ['ipilimumab', 'contains-1', '2013-10'], ['interferon', 'begins-on', '2013-10-05'], ['ipilimumab', 'begins-on', '2013-10-05'], ['alfa-2b interferon', 'contains-1', '2013-10-07'], ['interferon', 'contains-1', '2013-10-07'], ['ipilimumab', 'contains-1', '2013-10-07'], ['interferon', 'contains-1', '2013-10-08'], ['ipilimumab', 'contains-1', '2013-10-08'], ['alfa-2b interferon', 'contains-1', '2013-10-09'], ['interferon', 'ends-on', '2013-10-09'], ['ipilimumab', 'ends-on', '2013-10-09'], ['ipilimumab', 'ends-on', '2013-10-22'], ['alfa-2b interferon', 'begins-on', '2013-11-06'], ['interferon', 'begins-on', '2013-11-06'], ['ipilimumab', 'begins-on', '2013-11-06']]
# Proportion of timelines that needed fixing: 0.4528301886792453

# %%
# Testing
a = [1,1,2,3,4,5,0,6,-1,7]
b = deduplicate_identical_tuples(a)
print(a)
print(b)
timeline1 = [['ac','contains-1','2005'],['ac','begins-on','2005'],['ac','contains-1','2006']]
timeline1_a = remove_trivial_rels(timeline1)
print("timeline1:",timeline1)
print("timeline1_a:",timeline1_a)
timeline2 = [['ac','contains-1','2005'],['chemo','contains-1','2005'],['chemo','contains-1','2006']]
timeline2_a = remove_trivial_mentions(timeline2)
print("timeline2:",timeline2)
print("timeline2_a:",timeline2_a)

gold_sact = ['ac','chemo','tac','taxol','amg 330']
gold_rel = ['contains-1','begins-on','ends-on']
timeline3 = [['yeet','contains-1','2005'],['chemo','contains-1','2005'],['chemo','contains','2006'],['amg330','contains-1','2006']]
timeline3_a = remove_ungold_mentions_and_rels(timeline3,gold_sact,gold_rel)
print("timeline3:",timeline3)
print("timeline3_a:",timeline3_a)

timeline4 = [['yeet','contains-1','2004'],['chemo','contains-1','2005'],['chemotherapy','contains','2006'],['amg330','contains-1','2007']]
timeline4_a = normalize_general_mentions(timeline4)
print("timeline4:",timeline4)
print("timeline4_a:",timeline4_a)


base_dir = "/data/project/alstate/chemoTimeline2025/chemoTimelines2025_test_data/subtask1/Gold_PairWise_EventTimex/"
print("\nEntity extraction testing\n")
get_all_gold_entities(base_dir,"breast","patient02")

# Getting rels testing
#test_json_txt = ""
#with open("/data/project/alstate/chemoTimeline2025/test_results/tlinks/breast_task1.json","r") as f:
    #test_json_txt = f.read()
#test_json_eval = eval(test_json_txt)
#print(test_json_eval)
#print(type(test_json_eval))
print(get_all_predicted_rels_all_patients("/data/project/alstate/chemoTimeline2025/test_results/tlinks/breast_task1.json"))
print(get_all_predicted_entities_all_patients_all_cancers("/data/project/alstate/chemoTimeline2025/test_results/events_mods_timex/events_timex.csv"))

print("\nTesting pipeline on dev task 2 run 3:\n")
dev_timeline_input_file_dict = {
    "breast":"/data/project/alstate/chemoTimeline2025/test_results/dev/generated_timelines_round3/breast_dev_all_patients_generated_timelines.json",
    "ovarian":"/data/project/alstate/chemoTimeline2025/test_results/dev/generated_timelines_round3/ovarian_dev_all_patients_generated_timelines.json",
    "melanoma":"/data/project/alstate/chemoTimeline2025/test_results/dev/generated_timelines_round3/melanoma_dev_all_patients_generated_timelines.json"
}
dev_final_timeline_dir = "/data/project/alstate/chemoTimeline2025/test_results/dev/generated_timelines_final_round3/"
task2_dev_test(dev_timeline_input_file_dict,dev_final_timeline_dir)
# Out:
# [1, 1, 2, 3, 4, 5, 0, 6, -1, 7]
# [1, 2, 3, 4, 5, 0, 6, -1, 7]
# timeline1: [['ac', 'contains-1', '2005'], ['ac', 'begins-on', '2005'], ['ac', 'contains-1', '2006']]
# timeline1_a: [['ac', 'begins-on', '2005'], ['ac', 'contains-1', '2006']]
# timeline2: [['ac', 'contains-1', '2005'], ['chemo', 'contains-1', '2005'], ['chemo', 'contains-1', '2006']]
# timeline2_a: [['ac', 'contains-1', '2005'], ['chemo', 'contains-1', '2006']]
# timeline3: [['yeet', 'contains-1', '2005'], ['chemo', 'contains-1', '2005'], ['chemo', 'contains', '2006'], ['amg330', 'contains-1', '2006']]
# timeline3_a: [['chemo', 'contains-1', '2005'], ['amg 330', 'contains-1', '2006']]
# timeline4: [['yeet', 'contains-1', '2004'], ['chemo', 'contains-1', '2005'], ['chemotherapy', 'contains', '2006'], ['amg330', 'contains-1', '2007']]
# timeline4_a: [['yeet', 'contains-1', '2004'], ['chemo', 'contains-1', '2005'], ['chemo', 'contains', '2006'], ['amg330', 'contains-1', '2007']]
#
# Entity extraction testing
#
# {'patient104': ['begins-on'], 'patient129': ['contains-1', 'begins-on'], 'patient109': ['contains-1', 'begins-on', 'ends-on'], 'patient155': ['contains-1', 'begins-on'], 'patient114': ['contains-1', 'begins-on', 'ends-on'], 'patient143': ['contains-1', 'begins-on'], 'patient138': ['contains-1', 'begins-on', 'ends-on'], 'patient123': ['contains-1', 'begins-on'], 'patient174': ['contains-1', 'begins-on', 'ends-on'], 'patient119': ['ends-on'], 'patient181': ['begins-on', 'ends-on'], 'patient100': ['begins-on'], 'patient136': ['begins-on'], 'patient137': ['contains-1', 'begins-on', 'ends-on'], 'patient121': ['begins-on'], 'patient156': ['contains-1', 'begins-on', 'ends-on'], 'patient117': ['contains-1', 'begins-on', 'ends-on'], 'patient126': ['contains-1', 'begins-on', 'ends-on'], 'patient106': ['begins-on'], 'patient111': ['contains-1', 'begins-on', 'ends-on'], 'patient189': ['contains-1', 'begins-on', 'ends-on']}
# {'breast': {'patient138': ['chemotherapy', 'herceptin'], 'patient117': ['doxorubicin / cyclophosphamide', 'chemoradiation', 'adriamycin / cytoxan', '##le', 'geeu', 'a / c', 'chemo', 'liza', 'taxotere', 'tamoxifen', 'arimidex', 'che', 'docetaxel', 'adriamycin', 'cytoxan', 'chemotx', 'exemestane', 'anastrozole', 'chemotherapy', 'taxol', 'ac', 'tamoxi'], 'patient63': ['arimidex', 'chemoradiation', 'anastrozole'], 'patient143': ['chemotherapy', '##odex', 'arimidex', 'herceptin', 'faslodex', '##c', 'anastrazole', 'fulvestrant', 'anastrozole'], 'patient125': [], 'patient106': ['chemotherapy', 'arimidex', 'chemo', 'arimedex', 'tc', 'anastrozole'], 'patient158': ['acin', 'radionuclide'], 'patient132': ['chemotherapy', 'arimidex', 'chemoradiation', 'taxotere', 'cytoxan'], 'patient109': ['arimidex', 'euflexxa', 'aromasin', '##amestane', 'radiocolloid', 'anastrazole', '##le', 'paxil', 'anastrozole'], 'patient197': ['chemotherapy', 'chemoradiation'], 'patient123': ['chemotherapy', 'arimidex', 'taxotere', 'adriamycin / cytoxan', '##ran'], 'patient100': ['chemotherapy', 'arimidex', 'chemoradiation'], 'patient02': ['arimidex', 'chemoradiation', 'cytopath', 'tc', 'anastrazole', '##ytopa', 'anastrozole'], 'patient76': ['chemotherapy', 'chemo'], 'patient114': ['##sl', 'carboplatin', 'carbo', '##midex', '##geva', 'zom', 'chemo', 'zometa', 'taxotere', 'xrt / chemo', '##in', 'tamoxifen', 'faslodex', 'arimidex', 'megace', 'che', 'xgeva', '##umab', 'aromasin', '##x', '##p', '##emes', 'anastrozole', 'chemotherapy', 'taxol', '##slodex', 'herceptin', 'ar', 'bevacizumab', '##omasin', 'avastin', '##vac', 'kadcyla'], 'patient104': ['chemotherapy', 'chemoradiation', 'cytopath', '##ytopa', 'anastrozole'], 'patient142': ['chemotherapy', 'rhythmol', '##x', 'chem', 'bu'], 'patient121': ['chemotherapy', 'taxotere', 'aromasin', 'fem', 'tc', 'tamoxifen', 'cyclophosphamide', 'anastrozole'], 'patient118': ['chemotherapy', 'tamoxifen', 'chemoradiation'], 'patient155': ['chemotherapy', 'arimidex', 'herceptin', 'ag - sol', 'chemo', 'trastuzumab', '##xy', '- sol', 'hyclate', 'anastrozole'], 'patient101': ['chemoprevention', 'chemoradiation'], 'patient111': ['chemotherapy', 'femara', 'herceptin', 'chemoradiation', '##hib', 'chemo', 'ar', 'chemora', 'carboplatin', 'taxotere', 'chemotherapy /', 'peri - chemotherapy', 'post - chemotherapy', 't', 'tch', '##ion', 'a - c', 'aromatase inhibitor'], 'patient120': ['arimidex'], 'patient126': ['doxorubicin / cyclophosphamide', 'ac / taxol', 'chemoradiation', 'taxols', 'carboplatin', 'chem', '##motherapy', 'cyclophosphamide', 'a / c', 'chemo', 'chemotherapies', 'taxotere', 'gemcitabine', 'carboplatinum', 'ac - taxol', 'mirena', 'tm', 'adriamycin', 'cytoxan', 'paclitaxel', 'ge', 'adriamycin cytoxan', 'chemotherapy', 'taxol', 'ac', 'gemcitabine / carboplatin', 'carbo / gemzar', 'doxorubicin', '/', 'gemzar'], 'patient119': ['chemotherapy', 'cisplatin', 'chemoradiation', 'chemo', 'adriamycin', 'taxotere', 'cytoxan', 'adriamycin - cytoxan', 'cyclophosphamide'], 'patient189': ['doxorubicin / cyclophosphamide', 'geva', 'chemoradiation', 'taxols', '##ode', 'tamoxifen / lupron', 'adriamycin / cytoxan', 'halaven', 'geeu', 'a / c', 'chemo', 'chemotherapies', '##up', 'tam / lupron', 'leuprolide / tamoxifen', 'tamoxifen', 'faslodex', 'abraxane', '##ide / tamoxifen', 'xgeva', 'adriamycin', 'cytoxan', 'paclitaxel', 'a. c', 'hala', 'adriamycin cytoxan', 'lu', 'chemotherapy', 'taxol', 'herceptin', 'ac', 'leup', '##c'], 'patient137': ['chemoradiation', '##neo', 'carboplatin', 'carbo', 'chem', 'chemo', 'chemotherapies', 'taxotere', 'carboplatinum', '##tin', 'procrit', 'arimidex', 'che', 'anastrozole', 'chemotherapy', 'herceptin', 'tch', 'imc', 'biotin'], 'patient01': [], 'patient136': ['chemotherapy', 'taxol', 'tac', 'arimidex', 'ac', 'herceptin', 'chemo', 't', 'chemo -', 'radio'], 'patient115': ['tamoxifen'], 'patient129': ['chemotherapy', 'e - ca', 'arimidex'], 'patient156': ['chemotherapy', 'chemoradiation', 'chemo', 'taxotere', 'carboplatin', 'cy ...
#
# Testing pipeline on dev task 2 run 3:
#
# Had to change timeline
# Original timeline: [['carboplatin', 'begins-on', '2012-01-12'], ['chemotherapy', 'begins-on', '2012-01-12'], ['chemotherapy', 'contains-1', '2012-01-12'], ['paclitaxel', 'begins-on', '2012-01-12']]
# Fixed timeline: [['carboplatin', 'begins-on', '2012-01-12'], ['paclitaxel', 'begins-on', '2012-01-12']]
# Had to change timeline
# Original timeline: [['carboplatin', 'begins-on', '2012-04-03'], ['carboplatin', 'contains-1', '2012-04-24'], ['carboplatin', 'contains-1', '2012-05-15'], ['chemotherapy', 'contains-1', '2012-04-24'], ['chemotherapy', 'contains-1', '2012-05-15'], ['paclitaxel', 'begins-on', '2012-04-03'], ['paclitaxel', 'contains-1', '2012-04-24'], ['paclitaxel', 'contains-1', '2012-05-15']]
# Fixed timeline: [['carboplatin', 'begins-on', '2012-04-03'], ['carboplatin', 'contains-1', '2012-04-24'], ['carboplatin', 'contains-1', '2012-05-15'], ['paclitaxel', 'begins-on', '2012-04-03'], ['paclitaxel', 'contains-1', '2012-04-24'], ['paclitaxel', 'contains-1', '2012-05-15']]
# Had to change timeline
# Original timeline: [['carboplatin', 'begins-on', '2012-12'], ['carboplatin', 'contains-1', '2013-02'], ['carboplatin', 'ends-on', '2013-07-11'], ['chemo', 'contains-1', '2012-11-23'], ['chemo', 'contains-1', '2012-12-19'], ['chemo', 'contains-1', '2013-01-09'], ['chemotherapy', 'begins-on', '2012-11-23'], ['chemotherapy', 'begins-on', '2012-12-19'], ['chemotherapy', 'begins-on', '2013-01-09'], ['doxil', 'begins-on', '2013-10-24'], ['doxorubicin', 'begins-on', '2013-10'], ['doxorubicin', 'begins-on', '2013-10-08'], ['doxorubicin', 'contains-1', '2013-10-30'], ['doxorubicin', 'ends-on', '2013-10-08'], ['paclitaxel', 'begins-on', '2012-12'], ['paclitaxel', 'contains-1', '2013-02'], ['paclitaxel', 'ends-on', '2013-07-11']]
# Fixed timeline: [['carboplatin', 'begins-on', '2012-12'], ['carboplatin', 'contains-1', '2013-02'], ['carboplatin', 'ends-on', '2013-07-11'], ['chemo', 'contains-1', '2012-11-23'], ['chemo', 'contains-1', '2012-12-19'], ['chemo', 'contains-1', '2013-01-09'], ['chemo', 'begins-on', '2012-11-23'], ['chemo', 'begins-on', '2012-12-19'], ['chemo', 'begins-on', '2013-01-09'], ['doxil', 'begins-on', '2013-10-24'], ['doxorubicin', 'begins-on', '2013-10'], ['doxorubicin', 'begins-on', '2013-10-08'], ['doxorubicin', 'contains-1', '2013-10-30'], ['doxorubicin', 'ends-on', '2013-10-08'], ['paclitaxel', 'begins-on', '2012-12'], ['paclitaxel', 'contains-1', '2013-02'], ['paclitaxel', 'ends-on', '2013-07-11']]
# Proportion of timelines that needed fixing: 0.1111111111111111
